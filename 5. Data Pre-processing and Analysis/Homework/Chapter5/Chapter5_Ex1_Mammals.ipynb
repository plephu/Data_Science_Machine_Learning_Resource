# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %config Completer.use_jedi = False

# %%
df= pd.read_csv('input_data/mammals.csv',index_col=0)
df
# Out:
#                    Species    BodyWt  BrainWt  NonDreaming  Dreaming  \
# 1          Africanelephant  6654.000   5712.0          NaN       NaN
# 2   Africangiantpouchedrat     1.000      6.6          6.3       2.0
# 3                ArcticFox     3.385     44.5          NaN       NaN
# 4     Arcticgroundsquirrel     0.920      5.7          NaN       NaN
# 5            Asianelephant  2547.000   4603.0          2.1       1.8
# ..                     ...       ...      ...          ...       ...
# 58               Treehyrax     2.000     12.3          4.9       0.5
# 59               Treeshrew     0.104      2.5         13.2       2.6
# 60                  Vervet     4.190     58.0          9.7       0.6
# 61            Wateropossum     3.500      3.9         12.8       6.6
# 62    Yellow-belliedmarmot     4.050     17.0          NaN       NaN
#
#     TotalSleep  LifeSpan  Gestation  Predation  Exposure  Danger
# 1          3.3      38.6      645.0          3         5       3
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#             BodyWt      BrainWt  NonDreaming   Dreaming  TotalSleep  \
# count    62.000000    62.000000    48.000000  50.000000   58.000000
# mean    198.789984   283.134194     8.672917   1.972000   10.532759
# std     899.158011   930.278942     3.666452   1.442651    4.606760
# min       0.005000     0.140000     2.100000   0.000000    2.600000
# 25%       0.600000     4.250000     6.250000   0.900000    8.050000
# 50%       3.342500    17.250000     8.350000   1.800000   10.450000
# 75%      48.202500   166.000000    11.000000   2.550000   13.200000
# max    6654.000000  5712.000000    17.900000   6.600000   19.900000
#
#          LifeSpan   Gestation  Predation   Exposure     Danger
# count   58.000000   58.000000  62.000000  62.000000  62.000000
# mean    19.877586  142.353448   2.870968   2.419355   2.612903
# std     18.206255  146.805039   1.476414   1.604792   1.441252
# min      2.000000   12.000000   1.000000   1.000000   1.000000
# ...

# %%
body_range = df.BodyWt.values.ptp()
body_range
# Out:
# 6653.995

# %%
brain_range = df.BrainWt.values.ptp()
brain_range
# Out:
# 5711.86

# %%
plt.subplot(1,2,1)
plt.hist(df.BodyWt)
plt.subplot(1,2,2)
sns.distplot(df.BodyWt)
plt.show()
# Out:
# C:\Users\phamp\AppData\Local\Temp\ipykernel_20004\134985740.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.BodyWt)

# %%
df.BodyWt.skew()
# Out:
# 6.563608062833757

# %%
plt.subplot(1,2,1)
plt.hist(df.BrainWt)
plt.subplot(1,2,2)
sns.distplot(df.BrainWt)
plt.show()
# Out:
# C:\Users\phamp\AppData\Local\Temp\ipykernel_20004\4023771499.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.BrainWt)

# %%
df.BrainWt.skew()
# Out:
# 5.071589456939673

# %%
sns.lmplot(data=df, x ='BodyWt', y = 'BrainWt' )

# %%
# Quan hệ tuyến tính
# Chọn phương pháp chuẩn hóa là log nrmalization

# %%
df['BodyWt_log'] = np.log(df.BodyWt)
df['BrainWt_log'] = np.log(df.BrainWt)

# %%
df
# Out:
#                    Species    BodyWt  BrainWt  NonDreaming  Dreaming  \
# 1          Africanelephant  6654.000   5712.0          NaN       NaN
# 2   Africangiantpouchedrat     1.000      6.6          6.3       2.0
# 3                ArcticFox     3.385     44.5          NaN       NaN
# 4     Arcticgroundsquirrel     0.920      5.7          NaN       NaN
# 5            Asianelephant  2547.000   4603.0          2.1       1.8
# ..                     ...       ...      ...          ...       ...
# 58               Treehyrax     2.000     12.3          4.9       0.5
# 59               Treeshrew     0.104      2.5         13.2       2.6
# 60                  Vervet     4.190     58.0          9.7       0.6
# 61            Wateropossum     3.500      3.9         12.8       6.6
# 62    Yellow-belliedmarmot     4.050     17.0          NaN       NaN
#
#     TotalSleep  LifeSpan  Gestation  Predation  Exposure  Danger  BodyWt_log  \
# ...

# %%
plt.subplot(1,2,1)
plt.hist(df.BodyWt_log)
plt.subplot(1,2,2)
sns.distplot(df.BodyWt_log)
plt.show()
# Out:
# C:\Users\phamp\AppData\Local\Temp\ipykernel_20004\1430397659.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.BodyWt_log)

# %%
plt.subplot(1,2,1)
plt.hist(df.BrainWt_log)
plt.subplot(1,2,2)
sns.distplot(df.BrainWt_log)
plt.show()
# Out:
# C:\Users\phamp\AppData\Local\Temp\ipykernel_20004\1449610865.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.BrainWt_log)

# %%
sns.lmplot(data=df, x ='BodyWt_log', y = 'BrainWt_log' )
