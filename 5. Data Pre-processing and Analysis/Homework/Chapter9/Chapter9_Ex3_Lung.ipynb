# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %config Completer.use_jedi = False

# %%
data = pd.read_csv("./input_data/children_lung.txt", sep = " ")
data.head()
# Out:
#    Unnamed: 0  Unnamed: 1  age    FEV    ht  Unnamed: 5  Unnamed: 6  sex  \
# 0         NaN         NaN  9.0  1.708  57.0         NaN         NaN  0.0
# 1         NaN         NaN  8.0  1.724  67.5         NaN         NaN  0.0
# 2         NaN         NaN  7.0  1.720  54.5         NaN         NaN  0.0
# 3         NaN         NaN  9.0  1.558  53.0         NaN         NaN  1.0
# 4         NaN         NaN  9.0  1.895  57.0         NaN         NaN  1.0
#
#    Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  smoke  Unnamed: 13  \
# 0         NaN         NaN          NaN          NaN    0.0          NaN
# 1         NaN         NaN          NaN          NaN    0.0          NaN
# 2         NaN         NaN          NaN          NaN    0.0          NaN
# 3         NaN         NaN          NaN          NaN    0.0          NaN
# 4         NaN         NaN          NaN          NaN    0.0          NaN
#
#    Unnamed: 14
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 654 entries, 0 to 653
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   0 non-null      float64
#  1   Unnamed: 1   345 non-null    float64
#  2   age          654 non-null    float64
#  3   FEV          654 non-null    float64
#  4   ht           309 non-null    float64
#  5   Unnamed: 5   0 non-null      float64
#  6   Unnamed: 6   345 non-null    float64
#  7   sex          309 non-null    float64
#  8   Unnamed: 8   0 non-null      float64
#  9   Unnamed: 9   0 non-null      float64
#  10  Unnamed: 10  0 non-null      float64
#  11  Unnamed: 11  345 non-null    float64
#  12  smoke        309 non-null    float64
#  13  Unnamed: 13  0 non-null      float64
#  14  Unnamed: 14  0 non-null      float64
# dtypes: float64(15)
# memory usage: 76.8 KB

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'age', 'FEV', 'ht', 'Unnamed: 5',
#        'Unnamed: 6', 'sex', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'smoke', 'Unnamed: 13', 'Unnamed: 14'],
#       dtype='object')

# %%
data = data[['age','FEV','ht','sex','smoke']]
data.head()
# Out:
#    age    FEV    ht  sex  smoke
# 0  9.0  1.708  57.0  0.0    0.0
# 1  8.0  1.724  67.5  0.0    0.0
# 2  7.0  1.720  54.5  0.0    0.0
# 3  9.0  1.558  53.0  1.0    0.0
# 4  9.0  1.895  57.0  1.0    0.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 654 entries, 0 to 653
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     654 non-null    float64
#  1   FEV     654 non-null    float64
#  2   ht      309 non-null    float64
#  3   sex     309 non-null    float64
#  4   smoke   309 non-null    float64
# dtypes: float64(5)
# memory usage: 25.7 KB

# %%
data.describe()
# Out:
#               age         FEV          ht         sex       smoke
# count  654.000000  654.000000  309.000000  309.000000  309.000000
# mean     5.205369   35.209546   56.922330    0.498382    0.003236
# std      2.429315   31.541283    4.408388    0.500808    0.056888
# min      1.458000    0.791000   46.000000    0.000000    0.000000
# 25%      3.048500    2.040500   53.500000    0.000000    0.000000
# 50%      4.330000   59.000000   57.000000    0.000000    0.000000
# 75%      8.000000   65.000000   60.000000    1.000000    0.000000
# max      9.000000   74.000000   69.000000    1.000000    1.000000

# %%
plt.boxplot(data.FEV)
plt.show()

# %%
plt.boxplot(data.age)
plt.show()

# %%
sns.regplot(data=data, x='age', y='FEV')
plt.show()

# %%
plt.scatter(data.age,data.FEV)

# %%
FEV_lower_10 = data[data.FEV < 10]
FEV_lower_10.shapepe
# Out:
# (309, 5)

# %%
FEV_lower_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 309 entries, 0 to 308
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     309 non-null    float64
#  1   FEV     309 non-null    float64
#  2   ht      309 non-null    float64
#  3   sex     309 non-null    float64
#  4   smoke   309 non-null    float64
# dtypes: float64(5)
# memory usage: 14.5 KB

# %%
sns.pairplot(FEV_lower_10)
plt.show()

# %%
plt.scatter(FEV_lower_10.age, FEV_lower_10.FEV)
plt.show()

# %%
# Nhóm này có tuổi từ 3 đến 9, chủ yếu tập trung ở lứa tuổi từ 5 trở lên
# Có thể tuyến tính

# %%
plt.scatter(FEV_lower_10.ht, FEV_lower_10.FEV)
plt.show()

# %%
# ht tương đối tuyến tính so với FEV

# %%
# smoker: trẻ em không hút thuốc

# %%
FEV_upper_10 = data[data.FEV >= 10]
FEV_upper_10.shape
# Out:
# (345, 5)

# %%
FEV_upper_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 345 entries, 309 to 653
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     345 non-null    float64
#  1   FEV     345 non-null    float64
#  2   ht      0 non-null      float64
#  3   sex     0 non-null      float64
#  4   smoke   0 non-null      float64
# dtypes: float64(5)
# memory usage: 16.2 KB

# %%
plt.scatter(FEV_upper_10.age, FEV_upper_10.FEV)
plt.show()

# %%
# Nhóm này có tuổi từ 0 đến 6, tập trung nhiều từ 2 đến 5, tương đối tuyến tính

# %%
# Chia Làm 2 nhóm tương đương là FEV nhỏ hơn 19 và FEV Lớn hơn 19. 
# Quan sát thấy với nhóm có FEV_Lower_10 có 345 mẫu với đầy đủ dữ liệu, 
# Trong khi đó nhóm FEV_upper_10 chỉ có dữ liệu của age và FEV.
# Liệu có nên chia bài toán thành 2 phần, dự đoán theo từng phần? 
# Tham số của từng phần như thế nào?

# %% [markdown]
# #### 1: FEV_upper_10, dành cho dữ liệu chỉ có age

# %% [markdown]
# #### Dự đoán FEV từ age

# %% [markdown]
# ### Simple Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression()

# %%
X_u = FEV_upper_10[['age']]
Y_u = FEV_upper_10['FEV']

# %%
# Chia dữ liệu thành 2 phần, train và test 
from sklearn.model_selection import train_test_split

# %%
X_train_u, X_test_u, y_train_u, y_test_u = train_test_split(X_u,Y_u,test_size=0.2)

# %%
lm.fit(X_train_u,y_train_u)
# Out:
# LinearRegression()

# %%
b = lm.intercept_
b
# Out:
# 52.79677168882841

# %%
m = lm.coef_[0]
m
# Out:
# 3.8306148653453547

# %% [markdown]
# #### y=mx+b

# %%
# Predict trên X_train_u
yHat_train = lm.predict(X_train_u)

# %%
# Predict trên X_test_u
yHat_test = lm.predict(X_test_u)

# %%
reg_line = [(m* float(x)) + b for x in np.array(X_u)]

# %%
plt.figure(figsize=(10,6))
plt.plot(X_u, reg_line, color="orange", linewidth=3)
plt.scatter(X_train_u, y_train_u, color='red', label='Train Actual') 
plt.scatter(X_train_u, yHat_train, color='green', label='Train Predict') 
plt.scatter (X_test_u, y_test_u, color='black', label='Test Actual') 
plt.scatter(X_test_u, yHat_test, color='blue', label='Test Predict') 
plt.xlabel("Age")
plt.ylabel("FEV")
plt.legend (title="Notes: ")
plt.show()

# %%
# Find the MSE
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(Y_u, lm.predict(X_u)) 
print("The MSE of FEV and predicted value is: ", mse)
# Out:
# The MSE of FEV and predicted value is:  5.887910701285994

# %%
#Find the R^2
print('The R-square is: ', lm.score (X_u, Y_u))
# Out:
# The R-square is:  0.5784693110942492

# %%
#predict new data
X_new_u = pd.DataFrame(np.array([2, 3, 4, 5]))
y_new_u = lm.predict(X_new_u)
y_new_u
# Out:
# C:\Program Files\Python39\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([60.45800142, 64.28861628, 68.11923115, 71.94984602])

# %%
# regression plot
plt.figure(figsize=(6,6))
sns.regplot(x="age", y="FEV", data=FEV_upper_10) 
plt.ylim(50,)
# Out:
# (50.0, 76.88317610837797)

# %%
# Residual plot
plt.figure(figsize=(6,6))
sns.residplot(x=FEV_upper_10['age'], y=FEV_upper_10['FEV'])
plt.show()

# %%
Y_u_pred = lm.predict(X_u)

# %%
# Distribution plot plt.figure(figsize=(8,8))
ax1 = sns.distplot (Y_u, hist=False, color="r", label="Actual Value")
sns.distplot(Y_u_pred, hist=False, color="b",label="Fitted Values",ax=ax1)
plt.title('Actual vs Fitted Values for FEV')
plt.xlabel('FEV')
plt.ylabel('freq')
plt.show()
plt.close()
# Out:
# C:\Users\phamp\AppData\Local\Temp\ipykernel_13888\3452186663.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot (Y_u, hist=False, color="r", label="Actual Value")
# C:\Users\phamp\AppData\Local\Temp\ipykernel_13888\3452186663.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# ### Polinorminal Regression

# %%
X_u_p = FEV_upper_10[['age']]
Y_u_p = FEV_upper_10['FEV']

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pr=PolynomialFeatures (degree=2)
pr
# Out:
# PolynomialFeatures()

# %%
pr.fit(X_u_p)
# Out:
# PolynomialFeatures()

# %%
X_u_p_pr = pr.transform(X_u_p)

# %%
X_u_p.shape, X_u_p_pr.shape
# Out:
# ((345, 1), (345, 3))

# %%
lm1_pr = LinearRegression() 
lm1_pr.fit(X_u_p_pr, Y_u_p)
# Out:
# LinearRegression()

# %%
Y_u_p_hat_pr = lm1_pr.predict(X_u_p_pr)

# %%
lm1_pr.intercept_
# Out:
# 47.71519711405194

# %%
lm1_pr.coef_
# Out:
# array([ 0.        ,  6.98881744, -0.46863146])

# %%
# Find R^2
from sklearn.metrics import r2_score
r_squared = r2_score (Y_u_p, Y_u_p_hat_pr)
print('The R-square of Polinomial Regression model is: ', r_squared)
# Out:
# The R-square of Polinomial Regression model is:  0.5885078184205568

# %%
#Find the MSE
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(Y_u_p, Y_u_p_hat_pr) 
print('The MSE of FEV and predicted value is: ', mse)
# Out:
# The MSE of FEV and predicted value is:  5.747693544464183

# %%
# Distribution plot 
plt.figure(figsize=(8,8))
ax1 = sns.distplot (Y_u_p, hist=False, color="r", label="Actual Value")
sns.distplot (Y_u_p_hat_pr, hist=False, color="b", label="Fitted Values PR", ax=ax1)
plt.title('Actual vs Fitted Values for FEV')
plt.xlabel('FEV')
plt.ylabel('freq')
plt.show() 
plt.close()
# Out:
# C:\Users\phamp\AppData\Local\Temp\ipykernel_13888\187616266.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot (Y_u_p, hist=False, color="r", label="Actual Value")
# C:\Users\phamp\AppData\Local\Temp\ipykernel_13888\187616266.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
# PR tốt hơn so với SR Y có thể chọn PR

# %%
#predict new data
X_new_p = pd.DataFrame({'age': [2, 3, 4, 5]}) 
X_new_p_pr = pr.transform(X_new_p) 
Y_new_p = lm1_pr.predict(X_new_p_pr)
Y_new_p
# Out:
# array([59.81830614, 64.46396626, 68.17236347, 70.94349774])

# %% [markdown]
# #### Phần 2: FEV_lower_10, dành cho dữ liệu có age, ht

# %% [markdown]
# #### Dự đoán FEV từ age, ht

# %% [markdown]
# ### Multiple Linear Regression

# %%
# với X_i có age, ht => y_l

# %%
X_l = FEV_lower_10[['age','ht']]
Y_l = FEV_lower_10['FEV']

# %%
X_train_l, X_test_l, y_train_l, y_test_l = train_test_split(X_l,Y_l,test_size=0.2)

# %%
lm1 = LinearRegression()
lm1
# Out:
# LinearRegression()

# %%
#Train model
lm1.fit(X_train_l, y_train_l)
# Out:
# LinearRegression()

# %%
b = lm1.intercept_
b
# Out:
# -3.2768022248692383

# %%
m1, m2 = lm1.coef_[0], lm1.coef_[1]
m1, m2
# Out:
# (0.010737587564422817, 0.092032346358463)

# %%
# predict trên X trên X_train_1
yHat_train_l = lm1.predict(X_train_l)

# %%
# Predict trên X_test_u
yHat_test_1 = lm1.predict(X_test_l)

# %%
# Find the MSE
mse1 = mean_squared_error(Y_l, lm1.predict(X_l)) 
print('The MSE of price and predicted value is: ', mse1)
# Out:
# The MSE of price and predicted value is:  0.08541483540554001

# %%
#Find the R^2
print('The R-square is: ', lm1.score(X_l, Y_l))
# Out:
# The R-square is:  0.6725441971568791

# %%
# New prediction
age = [5, 6, 7, 8, 9]
ht = [49.5,55, 57, 60, 62]
X_l_new = pd.DataFrame({'age': age, 'ht':ht})
yHat_l_new = lm1.predict(X_l_new)
yHat_l_new
# Out:
# array([1.33248686, 1.84940235, 2.04420463, 2.33103926, 2.52584154])

# %%
yHat_l = lm1.predict(X_l)

# %%
# Đánh giá mô hình
# Distribution plot 
plt.figure(figsize=(8,8))
ax1 = sns.distplot(Y_l, hist=False, color="r", label="Actual Value")
sns.distplot (yHat_l, hist=False, color="b", label="Fitted Values", ax=ax1)
plt.title('Actual vs Fitted Values for FEV')
plt.xlabel('FEV')
plt.ylabel('freq')
plt.show()
plt.close()
# Out:
# C:\Users\phamp\AppData\Local\Temp\ipykernel_13888\3812980498.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(Y_l, hist=False, color="r", label="Actual Value")
# C:\Users\phamp\AppData\Local\Temp\ipykernel_13888\3812980498.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# ### Multiple Polynorminal

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pr = PolynomialFeatures(degree=2)
pr
# Out:
# PolynomialFeatures()

# %%
X_l_pr = pr.fit_transform(X_l)

# %%
X_l.shape, X_l_pr.shape
# Out:
# ((309, 2), (309, 6))

# %%
lm1_t = LinearRegression()

# %%
lm1_t.fit(X_l_pr, Y_l)
# Out:
# LinearRegression()

# %%
Yhat_t = lm1_t.predict(X_l_pr)

# %%
b1_t = lm1_t.intercept_

# %%
m1_t = lm1_t.coef_

# %%
b1_t, m1_t
# Out:
# (-0.42182399116131686,
#  array([ 0.        , -0.58556875,  0.06971195, -0.01718083,  0.01546802,
#         -0.00085841]))

# %%
X_l_new = pd.DataFrame({'age':age, 'ht':ht})
X_l_pr_new = pr.fit_transform(X_l_new)
yHat_l_t_new = lm1_t.predict(X_l_pr_new)
yHat_l_t_new
# Out:
# array([1.39657488, 1.78817454, 1.99368881, 2.31115186, 2.56998682])

# %%
# Find R^2
from sklearn.metrics import r2_score
r_squared = r2_score(Y_l, Yhat_t)
print('The R-square value is: ', r_squared)
# Out:
# The R-square value is:  0.6823609472684569

# %%
print('The MSE of price and predicted value using Polinormial Fit: ', mean_squared_error(Y_l, Yhat_t))
# Out:
# The MSE of price and predicted value using Polinormial Fit:  0.08285419641940044

# %%
# Đánh giá mô hình # Distribution plot plt.figure(figsize=(8,8))
ax1 = sns.distplot(Y_1, hist=False, color="r", label="Actual Value")
sns.distplot (Yhat_t, hist=False, color="b", label="Fitted Values MPR", ax=ax1)
sns.distplot (yHat_1, hist=False, color="g", label="Fitted Values MR", ax=ax1)
plt.title('Actual vs Fitted Values for FEV')
plt.xlabel('FEV')
plt.ylabel('freq')
plt.show()
plt.close()
# Out:
# C:\Users\phamp\AppData\Local\Temp\ipykernel_13888\3212196435.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(Y_1, hist=False, color="r", label="Actual Value")
# C:\Users\phamp\AppData\Local\Temp\ipykernel_13888\3212196435.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
# MPL cho kết quả tốt hơn so với MR => Có thể chọn MPL
