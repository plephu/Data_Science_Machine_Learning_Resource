# %%
from analysis.analyzer import TTTH_Analyzer
_analyzer =TTTH_Analyzer()
import pandas as pd

# %% [markdown]
# #### Univariate analyzer

# %%
df = pd.read_csv('./input_data/titanic/train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %% [markdown]
# ### Category

# %%
_analyzer.analyze_category_variable( variable_name='Pclass', df=df)
# Out:
# Class count of Pclass:
#
# ...
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64
# ...

# %% [markdown]
# #### Numeric

# %%
_analyzer.analyze_numeric_variable('Age', df=df)
# Out:
# =====
# central tendency of Age: {'mean': 29.69911764705882, 'median': 28.0, 'mode': 24.0, 'min': 0.42, 'max': 80.0, 'range': 79.58}
# =====
# Dispersion of Age:
#  {'range': 79.58, 'q1': 20.125, 'q3': 38.0, 'iqr': 17.875, 'var': 211.01912474630802, 'skew': 0.38910778230082704, 'kurtosis': 0.17827415364210353}
# =====

# %% [markdown]
# #### Bivariate analysis

# %%
_analyzer.analyze_category_vs_category('Pclass','Sex', df=df)
# Out:
# =====Analyze of Pclass and Sex=====
# {'var1': 'Pclass', 'var2': 'Sex', 'result': 'Reject H0 - Dependent'}

# %%
_analyzer.analyze_continous_vs_categories('Fare',['Sex','Pclass'], df=df)
# Out:
#                         sum_sq     df           F        PR(>F)
# C(Sex)            3.174857e+04    1.0   20.968394  5.337586e-06
# C(Pclass)         7.347122e+05    2.0  242.620968  9.763645e-85
# C(Sex):C(Pclass)  5.002816e+04    2.0   16.520591  9.034206e-08
# Residual          1.339992e+06  885.0         NaN           NaN
# ...
