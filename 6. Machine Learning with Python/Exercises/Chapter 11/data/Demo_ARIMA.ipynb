# %% [markdown]
# ### Load some data

# %%
import pandas as pd

# %%
data = pd.read_csv("candy_production.csv",index_col=0)

# %%
data.columns
# Out:
# Index(['IPG3113N'], dtype='object')

# %%
data
# Out:
#                   IPG3113N
# observation_date
# 1972-01-01         85.6945
# 1972-02-01         71.8200
# 1972-03-01         66.0229
# 1972-04-01         64.5645
# 1972-05-01         65.0100
# ...                    ...
# 2017-04-01        107.4288
# 2017-05-01        101.9209
# 2017-06-01        104.2022
# 2017-07-01        102.5861
# 2017-08-01        114.0613
#
# [548 rows x 1 columns]

# %%
data.isna().sum()
# Out:
# IPG3113N    0
# dtype: int64

# %%
data.index = pd.to_datetime(data.index)

# %%
data
# Out:
#                   IPG3113N
# observation_date
# 1972-01-01         85.6945
# 1972-02-01         71.8200
# 1972-03-01         66.0229
# 1972-04-01         64.5645
# 1972-05-01         65.0100
# ...                    ...
# 2017-04-01        107.4288
# 2017-05-01        101.9209
# 2017-06-01        104.2022
# 2017-07-01        102.5861
# 2017-08-01        114.0613
#
# [548 rows x 1 columns]

# %%
data.index.freq = 'MS' # D - day,

# %%
data
# Out:
#                   IPG3113N
# observation_date
# 1972-01-01         85.6945
# 1972-02-01         71.8200
# 1972-03-01         66.0229
# 1972-04-01         64.5645
# 1972-05-01         65.0100
# ...                    ...
# 2017-04-01        107.4288
# 2017-05-01        101.9209
# 2017-06-01        104.2022
# 2017-07-01        102.5861
# 2017-08-01        114.0613
#
# [548 rows x 1 columns]

# %%
data.columns = ['candy production']

# %%
data
# Out:
#                   candy production
# observation_date
# 1972-01-01                 85.6945
# 1972-02-01                 71.8200
# 1972-03-01                 66.0229
# 1972-04-01                 64.5645
# 1972-05-01                 65.0100
# ...                            ...
# 2017-04-01                107.4288
# 2017-05-01                101.9209
# 2017-06-01                104.2022
# 2017-07-01                102.5861
# 2017-08-01                114.0613
#
# [548 rows x 1 columns]

# %%
data.plot()
# Out:
# <Axes: xlabel='observation_date'>

# %% [markdown]
# ### Let's do some seasonal decompose

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomposition=seasonal_decompose(x=data,model='multiplicative')

# %%
decomposition.plot()
plt.show()

# %% [markdown]
# ### Let's try the ARIMA model

# %%
# !pip install pmdarima

# %%
from pmdarima.arima import auto_arima

# %%
model = auto_arima(data, start_p=2, start_q=2,
                      test='adf',
                      max_p=5, max_q=5,
                      m=12,             
                      d=1,          
                      seasonal=True,   
                      start_P=1, 
                      D=1, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,1,1)[12]             : AIC=2955.432, Time=2.65 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=3177.330, Time=0.16 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=3067.080, Time=0.50 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=2969.534, Time=0.81 sec
#  ARIMA(2,1,2)(0,1,1)[12]             : AIC=2960.282, Time=2.47 sec
#  ARIMA(2,1,2)(1,1,0)[12]             : AIC=inf, Time=2.75 sec
#  ARIMA(2,1,2)(2,1,1)[12]             : AIC=2956.153, Time=11.67 sec
#  ARIMA(2,1,2)(1,1,2)[12]             : AIC=2956.787, Time=12.93 sec
#  ARIMA(2,1,2)(0,1,0)[12]             : AIC=inf, Time=0.98 sec
#  ARIMA(2,1,2)(0,1,2)[12]             : AIC=2954.852, Time=8.48 sec
#  ARIMA(1,1,2)(0,1,2)[12]             : AIC=2951.313, Time=4.66 sec
#  ARIMA(1,1,2)(0,1,1)[12]             : AIC=2957.418, Time=1.37 sec
#  ARIMA(1,1,2)(1,1,2)[12]             : AIC=2953.311, Time=6.47 sec
#  ARIMA(1,1,2)(1,1,1)[12]             : AIC=2951.707, Time=1.95 sec
#  ARIMA(0,1,2)(0,1,2)[12]             : AIC=2958.148, Time=1.76 sec
#  ARIMA(1,1,1)(0,1,2)[12]             : AIC=2954.325, Time=2.34 sec
#  ARIMA(1,1,3)(0,1,2)[12]             : AIC=2951.129, Time=6.97 sec
#  ARIMA(1,1,3)(0,1,1)[12]             : AIC=inf, Time=2.41 sec
#  ARIMA(1,1,3)(1,1,2)[12]             : AIC=2953.126, Time=10.92 sec
#  ARIMA(1,1,3)(1,1,1)[12]             : AIC=2951.415, Time=2.52 sec
#  ARIMA(0,1,3)(0,1,2)[12]             : AIC=2960.055, Time=2.27 sec
#  ARIMA(2,1,3)(0,1,2)[12]             : AIC=2949.061, Time=6.50 sec
#  ARIMA(2,1,3)(0,1,1)[12]             : AIC=inf, Time=3.00 sec
#  ARIMA(2,1,3)(1,1,2)[12]             : AIC=2951.061, Time=15.39 sec
#  ARIMA(2,1,3)(1,1,1)[12]             : AIC=2949.457, Time=3.43 sec
#  ARIMA(3,1,3)(0,1,2)[12]             : AIC=inf, Time=15.32 sec
#  ARIMA(2,1,4)(0,1,2)[12]             : AIC=2952.228, Time=11.21 sec
#  ARIMA(1,1,4)(0,1,2)[12]             : AIC=2951.543, Time=6.53 sec
#  ARIMA(3,1,2)(0,1,2)[12]             : AIC=2949.561, Time=9.66 sec
#  ARIMA(3,1,4)(0,1,2)[12]             : AIC=inf, Time=16.42 sec
#  ARIMA(2,1,3)(0,1,2)[12] intercept   : AIC=inf, Time=14.02 sec
#
# Best model:  ARIMA(2,1,3)(0,1,2)[12]
# Total fit time: 188.555 seconds

# %%
model.aic()
# Out:
# 2949.0610782291615

# %% [markdown]
# ## Now split train and test

# %%
train = data.loc['1972-01-01':'2009-11-01']
test = data.loc['2009-12-01':]

# %%
train
# Out:
#                   candy production
# observation_date
# 1972-01-01                 85.6945
# 1972-02-01                 71.8200
# 1972-03-01                 66.0229
# 1972-04-01                 64.5645
# 1972-05-01                 65.0100
# ...                            ...
# 2009-07-01                 82.3126
# 2009-08-01                 89.0494
# 2009-09-01                101.1519
# 2009-10-01                123.6728
# 2009-11-01                117.0719
#
# [455 rows x 1 columns]

# %%
test
# Out:
#                   candy production
# observation_date
# 2009-12-01                116.5435
# 2010-01-01                100.3797
# 2010-02-01                 99.0155
# 2010-03-01                 91.9654
# 2010-04-01                 89.4914
# ...                            ...
# 2017-04-01                107.4288
# 2017-05-01                101.9209
# 2017-06-01                104.2022
# 2017-07-01                102.5861
# 2017-08-01                114.0613
#
# [93 rows x 1 columns]

# %%
test.shape
# Out:
# (93, 1)

# %%
model.fit(train)
# Out:
# ARIMA(order=(2, 1, 3), scoring_args={}, seasonal_order=(0, 1, 2, 12),
#       suppress_warnings=True, with_intercept=False)

# %%
# predict 93 steps ahead
prediction = model.predict(n_periods=len(test))

# %%
prediction
# Out:
# 2009-12-01    111.691476
# 2010-01-01    100.437303
# 2010-02-01     98.503555
# 2010-03-01     91.240547
# 2010-04-01     87.245782
#                  ...
# 2017-04-01     76.409765
# 2017-05-01     74.075352
# 2017-06-01     73.835813
# 2017-07-01     74.723836
# 2017-08-01     79.710457
# Freq: MS, Length: 93, dtype: float64

# %%
test
# Out:
#                   candy production
# observation_date
# 2009-12-01                116.5435
# 2010-01-01                100.3797
# 2010-02-01                 99.0155
# 2010-03-01                 91.9654
# 2010-04-01                 89.4914
# ...                            ...
# 2017-04-01                107.4288
# 2017-05-01                101.9209
# 2017-06-01                104.2022
# 2017-07-01                102.5861
# 2017-08-01                114.0613
#
# [93 rows x 1 columns]

# %%
prediction
# Out:
# 2010-01-01    102.131980
# 2010-02-01    100.132053
# 2010-03-01     95.286881
# 2010-04-01     88.799179
# 2010-05-01     89.645985
#                  ...
# 2017-05-01     85.983095
# 2017-06-01     85.866077
# 2017-07-01     84.801266
# 2017-08-01     92.361814
# 2017-09-01    101.271770
# Freq: MS, Length: 93, dtype: float64

# %%
from matplotlib import pyplot as plt
prediction_series = pd.Series(prediction,index=test.index)
fig, ax = plt.subplots(1, 1, figsize=(15, 5))
ax.plot(data)
ax.plot(prediction_series)

# %%
plt.figure(figsize=(10,10))
plt.plot(data,label='gt')
plt.plot(prediction_series,label='prediction',color='red')

# %%
prediction
# Out:
# 2010-01-01    101.429777
# 2010-02-01     98.632439
# 2010-03-01     92.291034
# 2010-04-01     86.407989
# 2010-05-01     85.782775
#                  ...
# 2017-05-01     71.056717
# 2017-06-01     71.199024
# 2017-07-01     70.107547
# 2017-08-01     77.203866
# 2017-09-01     85.346185
# Freq: MS, Length: 93, dtype: float64

# %% [markdown]
# ### Prediction for next 12 months

# %%
prediction_new = model.predict(n_periods=len(test)+12)

# %%
prediction_new
# Out:
# 2009-12-01    111.691476
# 2010-01-01    100.437303
# 2010-02-01     98.503555
# 2010-03-01     91.240547
# 2010-04-01     87.245782
#                  ...
# 2018-04-01     74.133359
# 2018-05-01     71.917093
# 2018-06-01     72.886219
# 2018-07-01     72.263646
# 2018-08-01     77.786391
# Freq: MS, Length: 105, dtype: float64

# %%
plt.plot(prediction_new,label='current pred',color='green')
plt.plot(prediction_new[len(test):],label='prediction for next 12 months',color='red')
