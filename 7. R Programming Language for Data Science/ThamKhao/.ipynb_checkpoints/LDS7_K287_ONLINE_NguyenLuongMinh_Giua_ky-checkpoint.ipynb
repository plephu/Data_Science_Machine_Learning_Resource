# %% [markdown]
# ## Đề thi giữa kỳ:
# # LDS7: R PROGRAMMING LANGUAGE FOR DATA SCIENCE
# ### Thời gian làm bài : <font color="red">từ khi nhận đề đến 20h30, Chủ Nhật ngày 27/08/2023 </font>
# #### Đọc kỹ các thông tin dưới đây trước khi làm bài:
# - Download folder được share sau đó đổi tên folder và tập tin đề thi ở phần được tô đỏ là họ và tên của bạn LDS7_k287_ONLINE_<font color="red">HoVaTen_</font>_Giua_ky và LDS7_k287_ONLINE_<font color="red">HoVaTen</font>_Giua_ky.ipynb
# - Làm bài thi vào tập tin LDS7_k287_ONLINE_<font color="red">HoVaTen_</font>_Giua_ky.ipynb
# - Upload folder chứa bài làm vào folder **LDS7_k287_ONLINE_HoVaTen** đã share trên Google Drive để GV chấm điểm.
# - Đến deadline, HV upload bài thi lên folder, HV không gửi bài thi sẽ không có điểm.
# - HV được sử dụng tài liệu.
# -	HV sẽ bị trừ điểm nếu bài làm giống nhau.

# %% [markdown]
# #### <font color="red">Chú ý: Tất cả các tập tin tạo ra ở Câu 3 HV nhớ nộp kèm luôn trong folder chứa bài thi.</font>

# %% [markdown]
# ## Câu 1: Vectors, Factors, Matrices, Arrays, và Lists (1.0 điểm)
# ### Yêu cầu : Hãy thực hiện các yêu cầu được liệt kê bên dưới, có in kết quả của từng câu:

# %% [markdown]
# #### 1. Tạo vector có tên là heights chứa chiều cao (centimet) của 10 cá nhân: 175, 162, 183, 170, 158, 168, 172, 159, 165, 157. In heights.

# %%
heights <- c(175, 162, 183, 170, 158, 168, 172, 159, 165, 157)
print(heights)
# Out:
#  [1] 175 162 183 170 158 168 172 159 165 157

# %% [markdown]
# #### 2. Tạo vector có tên là height_type từ vector heights ở Câu 1 với giá trị của từng phần tử như sau: nếu <160 : "Short", >=160 & <=170: "Average" , >170 : "Tall". Chuyển vector này thành factor height_type. In factor height_type.

# %%
height_type <- ifelse(heights < 160, 'Short', ifelse(heights >= 160 & heights <= 170, "Average", "Tall"))
height_type <- factor(height_type, levels = c("Short", "Average", "Tall"))
print(height_type)
# Out:
#  [1] Tall    Average Tall    Average Short   Average Tall    Short   Average
# [10] Short
# Levels: Short Average Tall

# %% [markdown]
# #### 3. Tạo matrix có tên student_scores (4,3) đại diện cho điểm của 4 học sinh trong 3 môn học, điểm là các giá trị ngẫu nhiên trong khoảng từ 7.0 đến 10.0. In student_scores.

# %%
student_scores <- matrix(runif(4 * 3, min = 7.0, max = 10.0), nrow=4, ncol=3)
print(student_scores)
# Out:
#          [,1]     [,2]     [,3]
# [1,] 9.179911 9.173296 9.618594
# [2,] 8.828058 9.086869 8.011651
# [3,] 9.795263 9.035369 7.460958
# [4,] 7.597095 9.449082 9.342080

# %% [markdown]
# #### 4. Tính điểm trung bình cho mỗi học sinh trong ma trận student_scores từ Câu 3. In kết quả.

# %%
average_scores <- rowMeans(student_scores)
print(average_scores)
# Out:
# [1] 9.323934 8.642193 8.763864 8.796086

# %% [markdown]
# #### 5. Tạo array có tên là sales_data (22, 12, 2) chứa doanh số bán hàng trong 1 năm của 2 sản phẩm; biết mỗi tháng ghi nhận doanh số 22 ngày, và 1 năm có 12 tháng, với các giá trị doanh thu ngẫu nhiên từ 1000 USD đến 5000 USD. In sales_data.

# %%
sales_data <- array(runif(22 * 12 * 2, min = 1000, max = 5000), dim = c(22, 12, 2))
print(sales_data)
# Out:
# , , 1
#
#           [,1]     [,2]     [,3]     [,4]     [,5]     [,6]     [,7]     [,8]
#  [1,] 3645.641 4296.143 2089.309 2196.667 3339.287 2777.529 2088.248 2708.233
#  [2,] 4570.264 2152.491 2019.668 4067.914 4396.418 2138.498 4246.636 2053.874
#  [3,] 3715.117 3035.276 2360.517 1401.437 4525.015 1528.720 2468.295 1900.333
#  [4,] 4694.249 3965.534 4725.618 3720.121 1769.911 1731.668 1198.149 1897.603
#  [5,] 2036.785 2416.056 1204.056 2539.676 3160.381 2765.592 4103.167 2734.064
#  [6,] 4278.752 1668.546 2897.242 2474.725 2203.043 2719.918 3224.262 4146.587
#  [7,] 3386.649 4921.685 3623.044 4229.648 2465.665 3517.903 4818.300 2207.485
#  [8,] 1602.563 3406.927 4695.286 4565.615 4405.446 1251.745 4276.222 4751.419
#  [9,] 4788.096 2911.574 4626.559 3483.554 4146.670 4983.368 4864.445 1554.510
# [10,] 3989.094 4829.273 4195.362 1707.029 3011.855 2837.696 4055.981 2898.933
# [11,] 2160.568 1677.652 1833.766 3557.154 1786.151 2818.785 2618.368 3457.043
# ...

# %% [markdown]
# #### 6. Tính tổng doanh số bán hàng cho từng sản phẩm trong năm, sử dụng array sales_data từ câu trên. In kết quả.

# %%
total_sales_per_product <- apply(sales_data, c(3), sum)
print(total_sales_per_product)
# Out:
# [1] 808137.2 790842.6

# %% [markdown]
# #### 7. Tạo một list có tên là data_collection chứa các thành phần sau: matrix student_scores từ Câu 3, array sales_data từ Câu 5, vector heights từ Câu 1 và factor height_type từ Câu 2. In data_collection.

# %%
data_collection <- list(
  student_scores = student_scores,
  sales_data = sales_data,
  heights = heights,
  height_type = height_type
)
print(data_collection)
# Out:
# $student_scores
#          [,1]     [,2]     [,3]
# [1,] 9.179911 9.173296 9.618594
# [2,] 8.828058 9.086869 8.011651
# [3,] 9.795263 9.035369 7.460958
# [4,] 7.597095 9.449082 9.342080
#
# $sales_data
# , , 1
#
#           [,1]     [,2]     [,3]     [,4]     [,5]     [,6]     [,7]     [,8]
#  [1,] 3645.641 4296.143 2089.309 2196.667 3339.287 2777.529 2088.248 2708.233
#  [2,] 4570.264 2152.491 2019.668 4067.914 4396.418 2138.498 4246.636 2053.874
#  [3,] 3715.117 3035.276 2360.517 1401.437 4525.015 1528.720 2468.295 1900.333
#  [4,] 4694.249 3965.534 4725.618 3720.121 1769.911 1731.668 1198.149 1897.603
#  [5,] 2036.785 2416.056 1204.056 2539.676 3160.381 2765.592 4103.167 2734.064
#  [6,] 4278.752 1668.546 2897.242 2474.725 2203.043 2719.918 3224.262 4146.587
#  [7,] 3386.649 4921.685 3623.044 4229.648 2465.665 3517.903 4818.300 2207.485
#  [8,] 1602.563 3406.927 4695.286 4565.615 4405.446 1251.745 4276.222 4751.419
# ...

# %% [markdown]
# #### 8. Tính trung bình chiều cao trong list my_list từ Câu 7. In kết quả.

# %%
average_height <- mean(data_collection$heights)
print(average_height)
# Out:
# [1] 166.9

# %% [markdown]
# #### 9. Tính trung bình doanh thu cho mỗi sản phẩm trong năm trong list my_list ở câu 7. In kết quả.

# %%
average_revenue_per_product <- apply(data_collection$sales_data, c(3), mean)
print(average_revenue_per_product)
# Out:
# [1] 3061.126 2995.616

# %% [markdown]
# #### 10. Cho vector có tên là crazy_sale_dates <- c("2023-09-09", "2023-10-10", "2023-11-11", "2023-12-12"), hãy chuyển các phần tử chứa chuỗi ngày của vector này sang kiểu ngày (Date) sau đó đưa vector này vào cuối list data_collection ở câu 7. In crazy_sale_dates và list data_collection.

# %%
crazy_sale_dates <- c("2023-09-09", "2023-10-10", "2023-11-11", "2023-12-12")
crazy_sale_dates <- as.Date(crazy_sale_dates)
data_collection$crazy_sale_dates <- crazy_sale_dates
print(crazy_sale_dates)
print(data_collection)
# Out:
# [1] "2023-09-09" "2023-10-10" "2023-11-11" "2023-12-12"
# $student_scores
#          [,1]     [,2]     [,3]
# [1,] 9.179911 9.173296 9.618594
# [2,] 8.828058 9.086869 8.011651
# [3,] 9.795263 9.035369 7.460958
# [4,] 7.597095 9.449082 9.342080
#
# $sales_data
# , , 1
#
#           [,1]     [,2]     [,3]     [,4]     [,5]     [,6]     [,7]     [,8]
#  [1,] 3645.641 4296.143 2089.309 2196.667 3339.287 2777.529 2088.248 2708.233
#  [2,] 4570.264 2152.491 2019.668 4067.914 4396.418 2138.498 4246.636 2053.874
#  [3,] 3715.117 3035.276 2360.517 1401.437 4525.015 1528.720 2468.295 1900.333
#  [4,] 4694.249 3965.534 4725.618 3720.121 1769.911 1731.668 1198.149 1897.603
#  [5,] 2036.785 2416.056 1204.056 2539.676 3160.381 2765.592 4103.167 2734.064
#  [6,] 4278.752 1668.546 2897.242 2474.725 2203.043 2719.918 3224.262 4146.587
#  [7,] 3386.649 4921.685 3623.044 4229.648 2465.665 3517.903 4818.300 2207.485
#  [8,] 1602.563 3406.927 4695.286 4565.615 4405.446 1251.745 4276.222 4751.419
# ...

# %% [markdown]
# ## Câu 2: Danh sách Sinh viên (Dataframe + Data Visualization) (1.0 điểm)
# ### Cho các tập tin dữ liệu liên quan đến sinh viên chứa trong folder **data**. Hãy thực hiện các yêu cầu được liệt kê bên dưới, có in kết quả của từng câu:

# %% [markdown]
# #### 1. Tạo dataframe df chứa danh sách các sinh viên khoa CN, khoa TO và khoa VL. Các danh sách này được đọc từ các tập tin sinh_vien_CN.csv, sinh_vien_TO.csv và sinh_vien_VL.csv trong folder data. Hiển thị thông tin chung của dữ liệu: head, tail, summary, số dòng, số cột của dữ liệu.

# %%
sinh_vien_CN <- read.csv("data/sinh_vien_CN.csv")
sinh_vien_TO <- read.csv("data/sinh_vien_TO.csv")
sinh_vien_VL <- read.csv("data/sinh_vien_VL.csv")
df <- rbind(sinh_vien_CN, sinh_vien_TO, sinh_vien_VL)

# %%
head(df)
# Out:
#   masv  ho             ten   gioitinh ngaysinh            email
# 1 C0001 Khương Thảo    Loan  False    1999-01-04 00:00:00 ktloan@gmail.com
# 2 C0002 Đặng Bạch      Ngọc  True     1999-11-11 00:00:00 dbngoc@gmail.com
# 3 C0003 Phạm Văn Minh  Thiện True     1999-11-23 00:00:00 pvmthien@gmail.com
# 4 C0004 Đinh Thị Thanh Dung  False    1999-01-19 00:00:00 dttdung@gmail.com
# 5 C0005 Trần Mạnh      Thiện True     1999-08-19 00:00:00 tmthien@gmail.com
# 6 C0006 Trần Văn Minh  Hiệu  True     1999-12-12 00:00:00 tvmhieu@gmail.com
#   didong    cmnd         hocbong makh
# 1 987314518 586900775484 2000000 CN
# 2 987587327 274387352269       0 CN
# 3 987858734 835772714136       0 CN
# 4 987508413 373064334392 1000000 CN
# 5 987579776 233384596844 1000000 CN
# 6 168595875  65746412487 1000000 CN

# %%
tail(df)
# Out:
#      masv  ho          ten   gioitinh ngaysinh            email
# 995  V0995 Đàm Văn     Vỹ    True     1999-03-30 00:00:00 dvvy@gmail.com
# 996  V0996 Trần Mạnh   Thăng True     1999-06-21 00:00:00 tmthang@gmail.com
# 997  V0997 Trần Vĩnh   Thiện True     1999-07-23 00:00:00 tvthien@gmail.com
# 998  V0998 Khương Thảo Hạnh  False    1999-08-16 00:00:00 kthanh@gmail.com
# 999  V0999 Đinh Ngọc   Ngọc  True     1999-05-25 00:00:00 dnngoc@gmail.com
# 1000 V1000 Lý Mạnh     Bảo   True     1999-06-03 00:00:00 lmbao@gmail.com
#      didong    cmnd         hocbong makh
# 995  168924061 492158542835 1000000 VL
# 996  987250062 768656897616 2000000 VL
# 997  987716502 468267857113 3000000 VL
# 998  913696608 702859343545       0 VL
# 999  913689521 187831202224 3000000 VL
# 1000 987656186 865173188581       0 VL

# %%
summary(df)
# Out:
#      masv                ho                ten              gioitinh
#  Length:1000        Length:1000        Length:1000        Length:1000
#  Class :character   Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character   Mode  :character
#
#
#
#    ngaysinh            email               didong               cmnd
#  Length:1000        Length:1000        Min.   :168002778   Min.   :1.124e+10
#  Class :character   Class :character   1st Qu.:168753078   1st Qu.:2.741e+11
#  Mode  :character   Mode  :character   Median :913486736   Median :5.128e+11
#                                        Mean   :695201267   Mean   :5.051e+11
#                                        3rd Qu.:987322301   3rd Qu.:7.358e+11
#                                        Max.   :987997679   Max.   :9.999e+11
#     hocbong            makh
#  Min.   :      0   Length:1000
#  1st Qu.:      0   Class :character
#  Median :1000000   Mode  :character
# ...

# %%
nrow(df)
# Out:
# [1] 1000

# %%
ncol(df)
# Out:
# [1] 10

# %% [markdown]
# #### 2. Tạo dataframe df_ket_qua với nội dung được đọc ra từ tập tin ket_qua.csv trong folder data. Hiển thị thông tin chung của dữ liệu: head, tail, summary, số dòng, số cột của dữ liệu.

# %%
df_ket_qua <- read.csv("data/ket_qua.csv")

# %%
head(df_ket_qua)
# Out:
#   masv  mamh diem
# 1 C0001 CSD1 7.0
# 2 C0001 CSD2 6.0
# 3 C0001 CTDL 9.0
# 4 C0001 KTLT 5.5
# 5 C0001 LQL1 7.0
# 6 C0001 LQL2 5.5

# %%
tail(df_ket_qua)
# Out:
#       masv  mamh diem
# 9995  V1000 LQL1 7.5
# 9996  V1000 LQL2 6.0
# 9997  V1000 NMLT 7.0
# 9998  V1000 TOA1 9.0
# 9999  V1000 TOA2 9.5
# 10000 V1000 TTNT 9.5

# %%
summary(df_ket_qua)
# Out:
#      masv               mamh                diem
#  Length:10000       Length:10000       Min.   : 4.000
#  Class :character   Class :character   1st Qu.: 6.000
#  Mode  :character   Mode  :character   Median : 7.000
#                                        Mean   : 7.214
#                                        3rd Qu.: 8.500
#                                        Max.   :10.000

# %%
nrow(df_ket_qua)
# Out:
# [1] 10000

# %%
ncol(df_ket_qua)
# Out:
# [1] 3

# %% [markdown]
# #### 3. Tạo dataframe df_dtb từ df_ket_qua bằng cách nhóm theo masv và tính điểm trung bình cho mỗi sinh viên (gợi ý: dùng group_by và summarize).

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ───────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.2     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.2     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.1
# ── Conflicts ─────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
group = group_by(df_ket_qua, masv)
df_dtb = summarize(group,  
                   dtb = mean(diem, na.rm = T))
head(df_dtb)
# Out:
#   masv  dtb
# 1 C0001 6.5
# 2 C0002 7.2
# 3 C0003 7.7
# 4 C0004 6.9
# 5 C0005 7.7
# 6 C0006 7.8

# %% [markdown]
# #### 4. Nối df_dtb vào df theo masv để có một dataframe chứa cả thông tin sinh viên và điểm trung bình.

# %%
df = left_join(df, df_dtb, by = "masv")
head(df)
# Out:
#   masv  ho             ten   gioitinh ngaysinh            email
# 1 C0001 Khương Thảo    Loan  False    1999-01-04 00:00:00 ktloan@gmail.com
# 2 C0002 Đặng Bạch      Ngọc  True     1999-11-11 00:00:00 dbngoc@gmail.com
# 3 C0003 Phạm Văn Minh  Thiện True     1999-11-23 00:00:00 pvmthien@gmail.com
# 4 C0004 Đinh Thị Thanh Dung  False    1999-01-19 00:00:00 dttdung@gmail.com
# 5 C0005 Trần Mạnh      Thiện True     1999-08-19 00:00:00 tmthien@gmail.com
# 6 C0006 Trần Văn Minh  Hiệu  True     1999-12-12 00:00:00 tvmhieu@gmail.com
#   didong    cmnd         hocbong makh dtb
# 1 987314518 586900775484 2000000 CN   6.5
# 2 987587327 274387352269       0 CN   7.2
# 3 987858734 835772714136       0 CN   7.7
# 4 987508413 373064334392 1000000 CN   6.9
# 5 987579776 233384596844 1000000 CN   7.7
# 6 168595875  65746412487 1000000 CN   7.8

# %% [markdown]
# #### 5. Cho biết 5 sinh viên có điểm lớn nhất của mỗi khoa, sắp tăng theo mã khoa và giảm theo điểm.

# %%
top_students <- df %>%
group_by(makh) %>%
arrange(makh, desc(dtb)) %>%
top_n(5)
print(top_students)
# Out:
# Selecting by dtb
# # A tibble: 16 × 11
# # Groups:   makh [3]
#    masv  ho     ten   gioitinh ngaysinh email didong    cmnd hocbong makh    dtb
#    <chr> <chr>  <chr> <chr>    <chr>    <chr>  <dbl>   <dbl>   <int> <chr> <dbl>
#  1 C0355 Văn T… Mai   False    1999-11… vtma… 9.87e8 8.55e11       0 CN     8.75
#  2 C0387 Lê Bạ… Ngân  False    1999-04… lbng… 9.13e8 6.47e11       0 CN     8.7
#  3 C0483 Lý Vĩ… Thiệu True     1999-06… lvth… 9.13e8 4.33e11       0 CN     8.7
#  4 C0154 Cao V… Bảo   True     1999-05… cvmb… 9.14e8 5.30e11 3000000 CN     8.6
#  5 C0052 Lê Th… Ly    False    1999-02… lttl… 1.68e8 8.74e11 1000000 CN     8.55
#  6 T0508 Trần … Nhung False    1999-11… tttn… 9.87e8 9.89e11 1000000 TO     8.35
#  7 T0537 Văn V… Vỹ    True     1999-09… vvvy… 9.14e8 8.76e11 2000000 TO     8.25
#  8 T0584 Đàm B… Ngân  True     1999-04… dbng… 1.69e8 1.66e11       0 TO     8.25
#  9 T0513 Thái … Kiệt  True     1999-04… tvmk… 9.14e8 7.54e11 3000000 TO     8.2
# ...

# %% [markdown]
# #### 6. Trong dataframe df tạo thêm cột **ketqua** với kết quả là Giỏi nếu điểm>=8, kết quả là Khá nếu điểm<8 và điểm >=6.5, kết quả là Trung bình nếu điểm <6.5 và điểm >=5, kết quả là Yếu nếu điểm<5

# %%
df <- df %>% 
mutate(ketqua = 
       ifelse(dtb >= 8, 'Giỏi', 
              ifelse(dtb >= 6.5, 'Khá', 
                     ifelse(dtb >= 5, 'Trung bình', 
                            'Yếu'))))
head(df)
# Out:
#   masv  ho             ten   gioitinh ngaysinh            email
# 1 C0001 Khương Thảo    Loan  False    1999-01-04 00:00:00 ktloan@gmail.com
# 2 C0002 Đặng Bạch      Ngọc  True     1999-11-11 00:00:00 dbngoc@gmail.com
# 3 C0003 Phạm Văn Minh  Thiện True     1999-11-23 00:00:00 pvmthien@gmail.com
# 4 C0004 Đinh Thị Thanh Dung  False    1999-01-19 00:00:00 dttdung@gmail.com
# 5 C0005 Trần Mạnh      Thiện True     1999-08-19 00:00:00 tmthien@gmail.com
# 6 C0006 Trần Văn Minh  Hiệu  True     1999-12-12 00:00:00 tvmhieu@gmail.com
#   didong    cmnd         hocbong makh dtb ketqua
# 1 987314518 586900775484 2000000 CN   6.5 Khá
# 2 987587327 274387352269       0 CN   7.2 Khá
# 3 987858734 835772714136       0 CN   7.7 Khá
# 4 987508413 373064334392 1000000 CN   6.9 Khá
# 5 987579776 233384596844 1000000 CN   7.7 Khá
# 6 168595875  65746412487 1000000 CN   7.8 Khá

# %% [markdown]
# #### 7. Cho biết mỗi khoa có bao nhiêu sinh viên Khá? Vẽ barplot thể hiện số lượng sinh viên Khá của từng khoa.

# %%
so_luong_sinh_vien_kha <- df %>%
  filter(ketqua == "Khá") %>%
  group_by(makh) %>%
  summarise(so_luong = n())
head(so_luong_sinh_vien_kha)
# Out:
#   makh so_luong
# 1 CN   420
# 2 TO    82
# 3 VL   325

# %%
library('plotrix')
barplot(so_luong_sinh_vien_kha$so_luong, 
        names.arg = so_luong_sinh_vien_kha$makh,
        xlab = "Khoa", 
        ylab = "So luong sinh vien",
        col='blue',
        main = "So luong sinh viên Kha cua moi khoa",
        border='red')
# Out:
# Plot with title “So luong sinh viên Kha cua moi khoa”

# %% [markdown]
# #### 8. Vẽ pie chart cho cột gioitinh: 1 pie chart cho tất cả SV, và mỗi khoa một pie chart riêng. Nhận xét chung, nhận xét từng khoa.

# %%
labels = paste0(c("Nu", "Nam"), " ", round(prop.table(table(df$gioitinh)) * 100, 2), "%")
labels
# Out:
# [1] "Nu 45.3%"  "Nam 54.7%"

# %%
pie(table(df$gioitinh), 
    labels = labels, 
    main = "Bieu do pie chart cho tat ca sinh vien")
# Out:
# Plot with title “Bieu do pie chart cho tat ca sinh vien”

# %%
for (ma in unique(df$makh)) {
    df_khoa <- df %>% filter(makh == ma)
    pie(table(df_khoa$gioitinh), 
      labels = paste0(c("Nu", "Nam"), " ", round(prop.table(table(df_khoa$gioitinh)) * 100, 2), "%"), 
      main = paste("Bieu do pie chart cho khoa", ma))
}
# Out:
# Plot with title “Bieu do pie chart cho khoa CN”
# Plot with title “Bieu do pie chart cho khoa TO”
# Plot with title “Bieu do pie chart cho khoa VL”

# %% [markdown]
# Nhận xét:
# - Toàn trường: Tỉ lệ sinh viên nam cao hơn sinh viên nữ, chênh lệch không nhiều ~ 10%
# - Từng khoa: Tỉ lệ sinh viên nam cao hơn sinh viên nữ, chênh lệch không nhiều. Tuy nhiên ở khoa VL có sự chênh lệch lớn ~ 15%

# %% [markdown]
# #### 9. Vẽ biểu đồ barplot thể hiện điểm trung bình của mỗi khoa. Nhận xét. (Gợi ý: tính điểm trung bình cho từng khoa và thể hiện lên biểu đồ)

# %%
df_avg_score <- df %>%
  group_by(makh) %>%
  summarise(dtb = mean(dtb))
head(df_avg_score)
# Out:
#   makh dtb
# 1 CN   7.2188
# 2 TO   7.2990
# 3 VL   7.1875

# %%
barplot(df_avg_score$dtb, 
        names.arg = df_avg_score$makh,
        xlab = "Khoa", 
        ylab = "Diem trung binh",
        main = "Diem trung binh cua moi khoa", 
        col = rainbow(length(df_avg_score$dtb)))
# Out:
# Plot with title “Diem trung binh cua moi khoa”

# %% [markdown]
# Nhận xét:
# - Điểm trung bình của các khoa không chênh lệch nhiều, tầm khoảng 7,1~7,2
# - Khoa có điểm trung bình cao nhất: Khoa TO
# - Khoa có điểm trung bình thấp nhất: Khoa VL

# %% [markdown]
# #### 10. Vẽ biểu đồ thể hiện số lượng SV theo ketqua(Giỏi, Khá....) của mỗi khoa. Nhận xét. (mỗi khoa 1 biểu đồ)

# %%
for (ma in unique(df$makh)) {
    df_khoa <- df %>%
    filter(ma == makh) %>%
    group_by(ketqua) %>%
    summarise(so_luong = n())
    
    barplot(df_khoa$so_luong, 
        names.arg = df_khoa$ketqua,
        xlab = "Ket qua", 
        ylab = "So luong sinh vien",
        col = rainbow(length(df_khoa$ketqua)),
        main = paste("So luong sinh viên theo ket qua cua khoa", ma))
}
# Out:
# Warning message in axis(if (horiz) 2 else 1, at = at.l, labels = names.arg, lty = axis.lty, :
# “conversion failure on 'Giỏi' in 'mbcsToSbcs': dot substituted for <e1>”
# Warning message in axis(if (horiz) 2 else 1, at = at.l, labels = names.arg, lty = axis.lty, :
# “conversion failure on 'Giỏi' in 'mbcsToSbcs': dot substituted for <bb>”
# Warning message in axis(if (horiz) 2 else 1, at = at.l, labels = names.arg, lty = axis.lty, :
# “conversion failure on 'Giỏi' in 'mbcsToSbcs': dot substituted for <8f>”
# Warning message in axis(if (horiz) 2 else 1, at = at.l, labels = names.arg, lty = axis.lty, :
# “conversion failure on 'Giỏi' in 'mbcsToSbcs': dot substituted for <e1>”
# Warning message in axis(if (horiz) 2 else 1, at = at.l, labels = names.arg, lty = axis.lty, :
# “conversion failure on 'Giỏi' in 'mbcsToSbcs': dot substituted for <bb>”
# Warning message in axis(if (horiz) 2 else 1, at = at.l, labels = names.arg, lty = axis.lty, :
# ...

# %% [markdown]
# Nhận xét:
# - Khoa CN: Sinh viên loại Khá chiếm đa số, Sinh viên Trung bình và giỏi gần bằng nhau.
# - Khoa TO: Sinh viên loại Khá chiếm đa số, Sinh viên giỏi có số lượng gấp đôi sinh viên trung bình.
# - Khoa VL: Sinh viên loại Khá chiếm đa số, Sinh viên giỏi có số lượng thấp sinh viên trung bình.

# %% [markdown]
# ## Câu 3: Cho dữ liệu fruit_data_with_colors.txt (Dataframe, Làm việc với tập tin) (1.0 điểm)
# ### Hãy thực hiện các yêu cầu được liệt kê bên dưới, có in kết quả của từng câu:

# %% [markdown]
# #### 1. Đọc dữ liệu. Xem thông tin dữ liệu với head(), tail(), str(), summary().

# %%
df <- read.table("fruit_data_with_colors.txt", header = TRUE)

# %%
head(df)
# Out:
#   fruit_label fruit_name fruit_subtype mass width height color_score
# 1 1           apple      granny_smith  192  8.4   7.3    0.55
# 2 1           apple      granny_smith  180  8.0   6.8    0.59
# 3 1           apple      granny_smith  176  7.4   7.2    0.60
# 4 2           mandarin   mandarin       86  6.2   4.7    0.80
# 5 2           mandarin   mandarin       84  6.0   4.6    0.79
# 6 2           mandarin   mandarin       80  5.8   4.3    0.77

# %%
tail(df)
# Out:
#    fruit_label fruit_name fruit_subtype mass width height color_score
# 54 4           lemon      unknown       120  6.0   8.4    0.74
# 55 4           lemon      unknown       116  6.1   8.5    0.71
# 56 4           lemon      unknown       116  6.3   7.7    0.72
# 57 4           lemon      unknown       116  5.9   8.1    0.73
# 58 4           lemon      unknown       152  6.5   8.5    0.72
# 59 4           lemon      unknown       118  6.1   8.1    0.70

# %%
str(df)
# Out:
# 'data.frame':	59 obs. of  7 variables:
#  $ fruit_label  : int  1 1 1 2 2 2 2 2 1 1 ...
#  $ fruit_name   : chr  "apple" "apple" "apple" "mandarin" ...
#  $ fruit_subtype: chr  "granny_smith" "granny_smith" "granny_smith" "mandarin" ...
#  $ mass         : int  192 180 176 86 84 80 80 76 178 172 ...
#  $ width        : num  8.4 8 7.4 6.2 6 5.8 5.9 5.8 7.1 7.4 ...
#  $ height       : num  7.3 6.8 7.2 4.7 4.6 4.3 4.3 4 7.8 7 ...
#  $ color_score  : num  0.55 0.59 0.6 0.8 0.79 0.77 0.81 0.81 0.92 0.89 ...

# %%
summary(df)
# Out:
#   fruit_label     fruit_name        fruit_subtype           mass
#  Min.   :1.000   Length:59          Length:59          Min.   : 76.0
#  1st Qu.:1.000   Class :character   Class :character   1st Qu.:140.0
#  Median :3.000   Mode  :character   Mode  :character   Median :158.0
#  Mean   :2.542                                         Mean   :163.1
#  3rd Qu.:4.000                                         3rd Qu.:177.0
#  Max.   :4.000                                         Max.   :362.0
#      width           height        color_score
#  Min.   :5.800   Min.   : 4.000   Min.   :0.5500
#  1st Qu.:6.600   1st Qu.: 7.200   1st Qu.:0.7200
#  Median :7.200   Median : 7.600   Median :0.7500
#  Mean   :7.105   Mean   : 7.693   Mean   :0.7629
#  3rd Qu.:7.500   3rd Qu.: 8.200   3rd Qu.:0.8100
#  Max.   :9.600   Max.   :10.500   Max.   :0.9300

# %% [markdown]
# #### 2. Hãy cho biết kiểu dữ liệu của cột fruit_name và fruit_subtype. Nếu kiểu dữ liệu không phải là factor thì hãy chuyển thành factor

# %%
class(df$fruit_name)
# Out:
# [1] "character"

# %%
class(df$fruit_subtype)
# Out:
# [1] "character"

# %%
df$fruit_name <- factor(df$fruit_name)
df$fruit_subtype <- factor(df$fruit_subtype)
head(df)
# Out:
#   fruit_label fruit_name fruit_subtype mass width height color_score
# 1 1           apple      granny_smith  192  8.4   7.3    0.55
# 2 1           apple      granny_smith  180  8.0   6.8    0.59
# 3 1           apple      granny_smith  176  7.4   7.2    0.60
# 4 2           mandarin   mandarin       86  6.2   4.7    0.80
# 5 2           mandarin   mandarin       84  6.0   4.6    0.79
# 6 2           mandarin   mandarin       80  5.8   4.3    0.77

# %% [markdown]
# #### 3. Có bao nhiêu loại fruit_name? Đó là những loại nào? Có bao nhiêu loại fruit_subtype? Đó là những loại nào?

# %%
nlevels(df$fruit_name)
# Out:
# [1] 4

# %%
levels(df$fruit_name)
# Out:
# [1] "apple"    "lemon"    "mandarin" "orange"

# %%
nlevels(df$fruit_subtype)
# Out:
# [1] 10

# %%
levels(df$fruit_subtype)
# Out:
#  [1] "braeburn"         "cripps_pink"      "golden_delicious" "granny_smith"
#  [5] "mandarin"         "selected_seconds" "spanish_belsan"   "spanish_jumbo"
#  [9] "turkey_navel"     "unknown"

# %% [markdown]
# #### 4. Hãy lọc ra tất cả các dòng dữ liệu có fruit_name là 'apple' chứa vào dataframe df_apple. Hãy cho biết có bao nhiêu dòng dữ liệu thỏa điều kiện này?

# %%
df_apple = df[df$fruit_name == 'apple',]
head(df_apple)
# Out:
#    fruit_label fruit_name fruit_subtype mass width height color_score
# 1  1           apple      granny_smith  192  8.4   7.3    0.55
# 2  1           apple      granny_smith  180  8.0   6.8    0.59
# 3  1           apple      granny_smith  176  7.4   7.2    0.60
# 9  1           apple      braeburn      178  7.1   7.8    0.92
# 10 1           apple      braeburn      172  7.4   7.0    0.89
# 11 1           apple      braeburn      166  6.9   7.3    0.93

# %%
nrow(df_apple)
# Out:
# [1] 19

# %% [markdown]
# #### 5. Hãy lưu dataframe df_apple vào tập tin apple.csv

# %%
write.csv(df_apple, 'apple.csv', row.names=FALSE)

# %% [markdown]
# #### 6. Hãy lọc ra tất cả các dòng dữ liệu có fruit_subtype là 'golden_delicious' chứa vào dataframe df_golden_delicious. Hãy cho biết có bao nhiêu dòng dữ liệu thỏa điều kiện này?

# %%
df_golden_delicious = df[df$fruit_subtype == 'golden_delicious',]
head(df_golden_delicious)
# Out:
#    fruit_label fruit_name fruit_subtype    mass width height color_score
# 14 1           apple      golden_delicious 164  7.3   7.7    0.70
# 15 1           apple      golden_delicious 152  7.6   7.3    0.69
# 16 1           apple      golden_delicious 156  7.7   7.1    0.69
# 17 1           apple      golden_delicious 156  7.6   7.5    0.67
# 18 1           apple      golden_delicious 168  7.5   7.6    0.73

# %%
nrow(df_golden_delicious)
# Out:
# [1] 5

# %% [markdown]
# #### 7. Hãy lưu dataframe df_golden_delicious vào tập tin golden_delicious.xlsx

# %%
library(openxlsx)

# %%
write.xlsx(df_golden_delicious, "golden_delicious.xlsx", append = FALSE)

# %% [markdown]
# #### 8. Hãy lưu dataframe df_golden_delicious vào tập tin golden_delicious.xml

# %%
library('XML')
library('methods')

# %%
doc = newXMLDoc()
top = newXMLNode('Fruits', doc = doc)
for (i in 1:nrow(df_golden_delicious)) {
    fruit_node = newXMLNode('Fruit', parent = top)
    row_data <- df_golden_delicious[i, ]
    for (col_name in names(row_data)) {
        newXMLNode(col_name, row_data[[col_name]], parent = fruit_node)
    }
}
doc
# Out:
# <?xml version="1.0"?>
# <Fruits>
#   <Fruit>
#     <fruit_label>1</fruit_label>
#     <fruit_name>apple</fruit_name>
#     <fruit_subtype>golden_delicious</fruit_subtype>
#     <mass>164</mass>
#     <width>7.3</width>
#     <height>7.7</height>
#     <color_score>0.7</color_score>
#   </Fruit>
#   <Fruit>
#     <fruit_label>1</fruit_label>
#     <fruit_name>apple</fruit_name>
#     <fruit_subtype>golden_delicious</fruit_subtype>
#     <mass>152</mass>
#     <width>7.6</width>
#     <height>7.3</height>
#     <color_score>0.69</color_score>
#   </Fruit>
#   <Fruit>
#     <fruit_label>1</fruit_label>
#     <fruit_name>apple</fruit_name>
#     <fruit_subtype>golden_delicious</fruit_subtype>
#     <mass>156</mass>
#     <width>7.7</width>
#     <height>7.1</height>
#     <color_score>0.69</color_score>
#   </Fruit>
#   <Fruit>
#     <fruit_label>1</fruit_label>
#     <fruit_name>apple</fruit_name>
#     <fruit_subtype>golden_delicious</fruit_subtype>
#     <mass>156</mass>
# ...

# %%
cat(saveXML(doc,
            indent=TRUE,
            prefix="<?xml version=\"1.0\" encoding=\"utf-8\" standalone=\"no\"?>\n"),
    file="golden_delicious.xml")

# %% [markdown]
# #### 9. Nhóm theo fruit_subtype, hãy thống kê số lượng mẫu theo từng subtype; max và min từng cột mass, width, height. (Gợi ý: dùng group_by() và summarize())

# %%
result <- df %>%
  group_by(fruit_subtype) %>%
  summarize(
    count = n(),
    max_mass = max(mass),
    min_mass = min(mass),
    max_width = max(width),
    min_width = min(width),
    max_height = max(height),
    min_height = min(height)
  )
result
# Out:
#    fruit_subtype    count max_mass min_mass max_width min_width max_height
# 1  braeburn          5    178      154      7.4       6.9        7.8
# 2  cripps_pink       6    170      140      7.6       7.3        7.9
# 3  golden_delicious  5    168      152      7.7       7.3        7.7
# 4  granny_smith      3    192      176      8.4       7.4        7.3
# 5  mandarin          5     86       76      6.2       5.8        4.7
# 6  selected_seconds  6    210      140      7.8       6.7        9.2
# 7  spanish_belsan    6    216      174      7.3       7.2       10.5
# 8  spanish_jumbo     3    362      342      9.6       9.0        9.4
# 9  turkey_navel     10    190      142      7.6       6.8        8.2
# 10 unknown          10    152      116      6.5       5.8        8.7
#    min_height
# 1  7.0
# 2  7.1
# 3  7.1
# 4  6.8
# 5  4.0
# 6  7.0
# 7  9.2
# 8  9.2
# 9  7.2
# 10 7.5

# %% [markdown]
# #### 10. Hãy lưu kết quả thống kê trên vào file subtype_summarize.json. Đọc file subtype_summarize.json vừa lưu. In nội dung.

# %%
library(jsonlite)

# %%
json_file <- "subtype_summarize.json"
json = toJSON(result)
write(json, file=json_file)

# %%
df <- fromJSON(json_file)
df
# Out:
#    fruit_subtype    count max_mass min_mass max_width min_width max_height
# 1  braeburn          5    178      154      7.4       6.9        7.8
# 2  cripps_pink       6    170      140      7.6       7.3        7.9
# 3  golden_delicious  5    168      152      7.7       7.3        7.7
# 4  granny_smith      3    192      176      8.4       7.4        7.3
# 5  mandarin          5     86       76      6.2       5.8        4.7
# 6  selected_seconds  6    210      140      7.8       6.7        9.2
# 7  spanish_belsan    6    216      174      7.3       7.2       10.5
# 8  spanish_jumbo     3    362      342      9.6       9.0        9.4
# 9  turkey_navel     10    190      142      7.6       6.8        8.2
# 10 unknown          10    152      116      6.5       5.8        8.7
#    min_height
# 1  7.0
# 2  7.1
# 3  7.1
# 4  6.8
# 5  4.0
# 6  7.0
# 7  9.2
# 8  9.2
# 9  7.2
# 10 7.5
