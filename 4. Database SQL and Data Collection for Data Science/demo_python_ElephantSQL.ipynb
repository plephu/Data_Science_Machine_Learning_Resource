# %%
from psycopg2 import connect

# %%
# kết nối tới database postgresql
cn = connect(host='john.db.elephantsql.com', user='cyzyxgky', password='DSC8oSoeODv71MrBnUQgB90KmevuQLGw', database='cyzyxgky')

# %%
# tạo cursor
cursor = cn.cursor()

# %%
# thực hiện truy vấn
sql = "select * from products limit 20"
results = cursor.execute(sql)

# xem dữ liệu
for row in cursor:
    print(row)
# Out:
# (1, 'Chai', 1, Decimal('18.00'), '10 boxes x 20 bags', '0')
# (2, 'Chang', 1, Decimal('19.00'), '24 - 12 oz bottles', '0')
# (3, 'Aniseed Syrup', 1, Decimal('10.00'), '12 - 550 ml bottles', '0')
# (4, "Chef Anton's Ca6/Seasoning", 2, Decimal('22.00'), '48 - 6 oz jars', '0')
# (5, "Chef Anton's Gumbo Mix", 2, Decimal('21.35'), '36 boxes', '1')
# (6, "Grandma's Boysenberry Spread", 3, Decimal('25.00'), '12 - 8 oz jars', '0')
# (7, "Uncle Bob's Organic Dried Pears", 3, Decimal('30.00'), '12 - 1 lb pkgs.', '0')
# (8, 'Northwoods Cranberry Sauce', 3, Decimal('40.00'), '12 - 12 oz jars', '0')
# (9, 'Mishi Kobe Niku', 4, Decimal('97.00'), '18 - 500 g pkgs.', '1')
# (10, 'Ikura', 4, Decimal('31.00'), '12 - 200 ml jars', '0')
# (11, 'Queso Cabrales', 5, Decimal('21.00'), '1 kg pkg.', '0')
# (12, 'Queso Manchego La Pastora', 5, Decimal('38.00'), '10 - 500 g pkgs.', '0')
# (13, 'Konbu', 6, Decimal('6.00'), '2 kg box', '0')
# (14, 'Tofu', 6, Decimal('23.25'), '40 - 100 g pkgs.', '0')
# ...

# %% [markdown]
# ## Sử dụng Magic SQL

# %%
# %load_ext sql

# %%
# kết nối
# %sql postgresql://cyzyxgky:DSC8oSoeODv71MrBnUQgB90KmevuQLGw@john.db.elephantsql.com/cyzyxgky

# %%
# thực hiện truy vấn
# %sql select * from products limit 20
# Out:
#  * postgresql://cyzyxgky:***@john.db.elephantsql.com/cyzyxgky
# 20 rows affected.
# [(1, 'Chai', 1, Decimal('18.00'), '10 boxes x 20 bags', '0'),
#  (2, 'Chang', 1, Decimal('19.00'), '24 - 12 oz bottles', '0'),
#  (3, 'Aniseed Syrup', 1, Decimal('10.00'), '12 - 550 ml bottles', '0'),
#  (4, "Chef Anton's Ca6/Seasoning", 2, Decimal('22.00'), '48 - 6 oz jars', '0'),
#  (5, "Chef Anton's Gumbo Mix", 2, Decimal('21.35'), '36 boxes', '1'),
#  (6, "Grandma's Boysenberry Spread", 3, Decimal('25.00'), '12 - 8 oz jars', '0'),
#  (7, "Uncle Bob's Organic Dried Pears", 3, Decimal('30.00'), '12 - 1 lb pkgs.', '0'),
#  (8, 'Northwoods Cranberry Sauce', 3, Decimal('40.00'), '12 - 12 oz jars', '0'),
#  (9, 'Mishi Kobe Niku', 4, Decimal('97.00'), '18 - 500 g pkgs.', '1'),
#  (10, 'Ikura', 4, Decimal('31.00'), '12 - 200 ml jars', '0'),
#  (11, 'Queso Cabrales', 5, Decimal('21.00'), '1 kg pkg.', '0'),
#  (12, 'Queso Manchego La Pastora', 5, Decimal('38.00'), '10 - 500 g pkgs.', '0'),
# ...
