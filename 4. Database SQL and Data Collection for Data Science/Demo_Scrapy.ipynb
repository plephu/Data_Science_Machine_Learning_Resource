# %%
import scrapy
from scrapy.selector import Selector
from scrapy.crawler import CrawlerProcess

import pandas as pd

# %%
# định nghĩa lớp kế thừa từ Spider
class giavang_spider(scrapy.Spider):
    name = "vang24h_spider"
    start_urls= ['https://www.24h.com.vn/gia-vang-hom-nay-c425.html',]
    
    def parse(self, response):
        banggia = response.css('table.gia-vang-search-data-table')
        ngay = response.css('span.inputDate::text').get()
        for tr in banggia.css('tbody > tr'):
            loai = tr.css('h2::text').get(default='')
            gias = tr.css('span.fixW').getall()
            giamua = gias[0]
            giaban = gias[1]
            yield {'ngay': ngay, 'loai' : loai, 'giamua' : giamua, 'giaban': giaban}

# %%
process = CrawlerProcess()
process.crawl(giavang_spider)
process.start()
# Out:
# 2023-03-11 17:25:58 [scrapy.utils.log] INFO: Scrapy 2.8.0 started (bot: scrapybot)
# 2023-03-11 17:25:58 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.9.12, cssselect 1.2.0, parsel 1.7.0, w3lib 2.1.1, Twisted 22.10.0, Python 3.9.13 (tags/v3.9.13:6de2ca5, May 17 2022, 16:36:42) [MSC v.1929 64 bit (AMD64)], pyOpenSSL 23.0.0 (OpenSSL 3.0.8 7 Feb 2023), cryptography 39.0.2, Platform Windows-10-10.0.22621-SP0
# 2023-03-11 17:25:58 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-03-11 17:25:58 [py.warnings] WARNING: C:\Program Files\Python39\lib\site-packages\scrapy\utils\request.py:232: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-03-11 17:25:58 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2023-03-11 17:25:58 [scrapy.extensions.telnet] INFO: Telnet Password: 9e3f6f93672b529e
# 2023-03-11 17:25:58 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2023-03-11 17:25:59 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-03-11 17:25:59 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-03-11 17:25:59 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-03-11 17:25:59 [scrapy.core.engine] INFO: Spider opened
# 2023-03-11 17:25:59 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-03-11 17:25:59 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2023-03-11 17:25:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.24h.com.vn/gia-vang-hom-nay-c425.html> (referer: None)
# 2023-03-11 17:25:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.24h.com.vn/gia-vang-hom-nay-c425.html>
# {'ngay': '\r\n                                    2023-03-11                                ', 'loai': 'DOJI HN', 'giamua': '<span class="fixW">65,950</span>', 'giaban': '<span class="fixW">66,750</span>'}
# 2023-03-11 17:25:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.24h.com.vn/gia-vang-hom-nay-c425.html>
# {'ngay': '\r\n                                    2023-03-11                                ', 'loai': 'DOJI SG', 'giamua': '<span class="fixW">66,000</span>', 'giaban': '<span class="fixW">66,800</span>'}
# 2023-03-11 17:25:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.24h.com.vn/gia-vang-hom-nay-c425.html>
# {'ngay': '\r\n                                    2023-03-11                                ', 'loai': 'Phú Qúy SJC', 'giamua': '<span class="fixW">66,000</span>', 'giaban': '<span class="fixW">66,800</span>'}
# 2023-03-11 17:25:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.24h.com.vn/gia-vang-hom-nay-c425.html>
# {'ngay': '\r\n                                    2023-03-11                                ', 'loai': 'VIETINBANK GOLD', 'giamua': '<span class="fixW">65,850</span>', 'giaban': '<span class="fixW">66,570</span>'}
# 2023-03-11 17:25:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.24h.com.vn/gia-vang-hom-nay-c425.html>
# {'ngay': '\r\n                                    2023-03-11                                ', 'loai': 'SJC TP HCM', 'giamua': '<span class="fixW">66,000</span>', 'giaban': '<span class="fixW">66,800</span>'}
# 2023-03-11 17:25:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.24h.com.vn/gia-vang-hom-nay-c425.html>
# {'ngay': '\r\n                                    2023-03-11                                ', 'loai': 'SJC Hà Nội', 'giamua': '<span class="fixW">66,000</span>', 'giaban': '<span class="fixW">66,820</span>'}
# 2023-03-11 17:25:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.24h.com.vn/gia-vang-hom-nay-c425.html>
# {'ngay': '\r\n                                    2023-03-11                                ', 'loai': 'SJC Đà Nẵng', 'giamua': '<span class="fixW">66,000</span>', 'giaban': '<span class="fixW">66,820</span>'}
# 2023-03-11 17:25:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.24h.com.vn/gia-vang-hom-nay-c425.html>
# {'ngay': '\r\n                                    2023-03-11                                ', 'loai': 'PNJ TP.HCM', 'giamua': '<span class="fixW">53,900</span>', 'giaban': '<span class="fixW">54,900</span>'}
# 2023-03-11 17:25:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.24h.com.vn/gia-vang-hom-nay-c425.html>
# {'ngay': '\r\n                                    2023-03-11                                ', 'loai': 'PNJ HN', 'giamua': '<span class="fixW">0</span>', 'giaban': '<span class="fixW">53,900</span>'}
# 2023-03-11 17:25:59 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-03-11 17:25:59 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 240,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 116139,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 0.241278,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 3, 11, 10, 25, 59, 582584),
#  'httpcompression/response_bytes': 628021,
#  'httpcompression/response_count': 1,
#  'item_scraped_count': 9,
#  'log_count/DEBUG': 11,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2023, 3, 11, 10, 25, 59, 341306)}
# 2023-03-11 17:25:59 [scrapy.core.engine] INFO: Spider closed (finished)
