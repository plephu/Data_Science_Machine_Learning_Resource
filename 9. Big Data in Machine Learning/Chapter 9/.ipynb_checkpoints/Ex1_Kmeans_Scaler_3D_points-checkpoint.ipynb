# %%
import findspark
findspark.init()

# %%
import pyspark

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('kmeans_3D_point').getOrCreate()

# %%
# Loads data.
data = spark.read.csv("data3D.csv", header=True, inferSchema=True)

# %%
data.show(3)
# Out:
# +------+-----------------+------------------+------------------+
# |    id|                x|                 y|                 z|
# +------+-----------------+------------------+------------------+
# |point0|5.647627534046943|-6.356222340123802|-7.240816026826695|
# |point1|4.414367138680041|-10.32624175635328| 8.963324308916228|
# |point2|5.005396944639823|-9.301070062115645| 10.35473056351597|
# +------+-----------------+------------------+------------------+
# only showing top 3 rows

# %%
from pyspark.sql.functions import col

# %%
data = data.select(['x', 'y', 'z'])

# %%
data.show(3)
# Out:
# +-----------------+------------------+------------------+
# |                x|                 y|                 z|
# +-----------------+------------------+------------------+
# |5.647627534046943|-6.356222340123802|-7.240816026826695|
# |4.414367138680041|-10.32624175635328| 8.963324308916228|
# |5.005396944639823|-9.301070062115645| 10.35473056351597|
# +-----------------+------------------+------------------+
# only showing top 3 rows

# %% [markdown]
# ### Format from data

# %%
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import VectorAssembler

# %%
data.columns
# Out:
# ['x', 'y', 'z']

# %%
vec_assembler = VectorAssembler(inputCols = data.columns, outputCol='features')

# %%
final_data = vec_assembler.transform(data)

# %% [markdown]
# ### Scale the Data

# %%
from pyspark.ml.feature import StandardScaler

# %%
scaler = StandardScaler(inputCol="features", 
 outputCol="scaledFeatures", 
 withStd=True, 
 withMean=False)

# %%
# Compute summary statistics by fitting the StandardScaler
scalerModel = scaler.fit(final_data)

# %%
# Normalize each feature to have unit standard deviation.
final_data = scalerModel.transform(final_data)

# %%
final_data.show(3, False)
# Out:
# +-----------------+------------------+------------------+---------------------------------------------------------+------------------------------------------------------------+
# |x                |y                 |z                 |features                                                 |scaledFeatures                                              |
# +-----------------+------------------+------------------+---------------------------------------------------------+------------------------------------------------------------+
# |5.647627534046943|-6.356222340123802|-7.240816026826695|[5.647627534046943,-6.356222340123802,-7.240816026826695]|[1.0159673512169785,-0.8133579916042428,-1.1300631023636816]|
# |4.414367138680041|-10.32624175635328|8.963324308916228 |[4.414367138680041,-10.32624175635328,8.963324308916228] |[0.7941127247055376,-1.321371532702518,1.398892340103383]   |
# |5.005396944639823|-9.301070062115645|10.35473056351597 |[5.005396944639823,-9.301070062115645,10.35473056351597] |[0.9004347126254749,-1.1901880174546229,1.616046989924021]  |
# +-----------------+------------------+------------------+---------------------------------------------------------+------------------------------------------------------------+
# only showing top 3 rows

# %% [markdown]
# ### Train the Model and Evaluate

# %% [markdown]
# #### Seleck k with minimun WSSSE: k between 2 - 10

# %%
from pyspark.ml.clustering import KMeans
from pyspark.ml.evaluation import ClusteringEvaluator

# %%
# Trains a k-means model.
k_list = []
silhouette_list = []
for k in range(2,11): 
    kmeans = KMeans(featuresCol='scaledFeatures',k=k)
    model = kmeans.fit(final_data)
    predictions  = model.transform(final_data)
    evaluator = ClusteringEvaluator()
    silhouette = evaluator.evaluate(predictions)
    k_list.append(k)
    silhouette_list.append(silhouette)
    print("With k =", k, "Set Sum of Silhouette = " + str(silhouette))
# Out:
# With k = 2 Set Sum of Silhouette = 0.7933114774641375
# With k = 3 Set Sum of Silhouette = 0.9407566693614594
# With k = 4 Set Sum of Silhouette = 0.9235528500030936
# With k = 5 Set Sum of Silhouette = 0.8585692233486628
# With k = 6 Set Sum of Silhouette = 0.7520519786911748
# With k = 7 Set Sum of Silhouette = 0.7390971235874598
# With k = 8 Set Sum of Silhouette = 0.6763057414135376
# With k = 9 Set Sum of Silhouette = 0.559319772384394
# With k = 10 Set Sum of Silhouette = 0.52727608488747

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.plot(k_list, silhouette_list)
plt.show()

# %% [markdown]
# - According to Elbow Method, we choose k = 5. Look like there is very little gain after k=5, so
# we stick to that choice when processing the full data set.

# %% [markdown]
# #### Select k = 5

# %%
# Trains a k-means model.
kmeans = KMeans(featuresCol='scaledFeatures',k=5)
model = kmeans.fit(final_data)

# %%
# Evaluate clustering by computing Within Set Sum of Squared Errors.
wssse = model.computeCost(final_data)
print("Within Set Sum of Squared Errors = " + str(wssse))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 2
#       1 # Evaluate clustering by computing Within Set Sum of Squared Errors.
# ----> 2 wssse = model.computeCost(final_data)
#       3 print("Within Set Sum of Squared Errors = " + str(wssse))
#
# AttributeError: 'KMeansModel' object has no attribute 'computeCost'

# %% [markdown]
# Within Set Sum of Squared Errors = 72720.18504204816

# %%
# Shows the result.
centers = model.clusterCenters()
print("Cluster Centers: ")
for center in centers:
    print(center)
# Out:
# Cluster Centers:
# [-0.45182036  1.15367577  0.72369935]
# [ 0.74896823 -1.2269015   1.46702482]
# [ 0.35335011 -0.87989042 -1.07356065]
# [ 1.19781758 -0.73649905 -0.99420824]
# [-1.59030525  0.93719373  0.31581855]

# %%
predictions = model.transform(final_data)

# %%
predictions.select("prediction").show(5)
# Out:
# +----------+
# |prediction|
# +----------+
# |         3|
# |         1|
# |         1|
# |         1|
# |         4|
# +----------+
# only showing top 5 rows

# %%
# Check number points of each cluster

# %%
predictions.groupBy('prediction').count().show()
# Out:
# +----------+------+
# |prediction| count|
# +----------+------+
# |         1|200000|
# |         3|199986|
# |         4|199983|
# |         2|200014|
# |         0|200017|
# +----------+------+

# %%
# Our clustering algorithm created 5 equally sized clusters with K=5

# %%
data_result = predictions.select("prediction")
data_result.columns
# Out:
# ['prediction']

# %%
type(data_result)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
final_data.show(3, False)
# Out:
# +-----------------+------------------+------------------+---------------------------------------------------------+------------------------------------------------------------+
# |x                |y                 |z                 |features                                                 |scaledFeatures                                              |
# +-----------------+------------------+------------------+---------------------------------------------------------+------------------------------------------------------------+
# |5.647627534046943|-6.356222340123802|-7.240816026826695|[5.647627534046943,-6.356222340123802,-7.240816026826695]|[1.0159673512169785,-0.8133579916042428,-1.1300631023636816]|
# |4.414367138680041|-10.32624175635328|8.963324308916228 |[4.414367138680041,-10.32624175635328,8.963324308916228] |[0.7941127247055376,-1.321371532702518,1.398892340103383]   |
# |5.005396944639823|-9.301070062115645|10.35473056351597 |[5.005396944639823,-9.301070062115645,10.35473056351597] |[0.9004347126254749,-1.1901880174546229,1.616046989924021]  |
# +-----------------+------------------+------------------+---------------------------------------------------------+------------------------------------------------------------+
# only showing top 3 rows

# %%
temp = final_data.select("scaledFeatures").rdd.map(lambda x: x[0].toArray().tolist()).toDF()

# %%
temp.show(3)
# Out:
# +------------------+-------------------+-------------------+
# |                _1|                 _2|                 _3|
# +------------------+-------------------+-------------------+
# |1.0159673512169785|-0.8133579916042428|-1.1300631023636816|
# |0.7941127247055376| -1.321371532702518|  1.398892340103383|
# |0.9004347126254749|-1.1901880174546229|  1.616046989924021|
# +------------------+-------------------+-------------------+
# only showing top 3 rows

# %%
import pyspark.sql.functions as f

# %%
# since there is no common column between these two dataframes add row_index so t
temp=temp.withColumn('row_index', f.monotonically_increasing_id())
data_result=data_result.withColumn('row_index', f.monotonically_increasing_id())
temp = temp.join(data_result, on=["row_index"]).sort("row_index").drop("row_index")

# %%
temp = temp.select(col("_1").alias("x_scale"), 
                   col("_2").alias("y_scale"), 
                   col("_3").alias("z_scale"), 
                   "prediction")

# %%
df = temp.toPandas()

# %%
df.head(3)
# Out:
#     x_scale   y_scale   z_scale  prediction
# 0  1.015967 -0.813358 -1.130063           3
# 1  0.794113 -1.321372  1.398892           1
# 2  0.900435 -1.190188  1.616047           1

# %%
centers_df = pd.DataFrame(centers)
centers_df.head()
# Out:
#           0         1         2
# 0 -0.451820  1.153676  0.723699
# 1  0.748968 -1.226902  1.467025
# 2  0.353350 -0.879890 -1.073561
# 3  1.197818 -0.736499 -0.994208
# 4 -1.590305  0.937194  0.315819

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
threedee = plt.figure(figsize=(12,10)).add_subplot(projection='3d')
threedee.scatter(df.x_scale, df.y_scale, 
                 df.z_scale, 
                 c=df.prediction)
threedee.set_xlabel('x')
threedee.set_ylabel('y')
threedee.set_zlabel('z')
plt.show()

# %% [markdown]
# ### Combine results

# %%
# since there is no common column between these two dataframes add row_index so t
final_data=final_data.withColumn('row_index', f.monotonically_increasing_id())
temp=temp.withColumn('row_index', f.monotonically_increasing_id())
final_data = final_data.join(temp, on=["row_index"]).sort("row_index").drop("row_index")

# %%
final_data.show(3, False)
# Out:
# +-----------------+------------------+------------------+---------------------------------------------------------+------------------------------------------------------------+------------------+-------------------+-------------------+----------+
# |x                |y                 |z                 |features                                                 |scaledFeatures                                              |x_scale           |y_scale            |z_scale            |prediction|
# +-----------------+------------------+------------------+---------------------------------------------------------+------------------------------------------------------------+------------------+-------------------+-------------------+----------+
# |5.647627534046943|-6.356222340123802|-7.240816026826695|[5.647627534046943,-6.356222340123802,-7.240816026826695]|[1.0159673512169785,-0.8133579916042428,-1.1300631023636816]|1.0159673512169785|-0.8133579916042428|-1.1300631023636816|3         |
# |4.414367138680041|-10.32624175635328|8.963324308916228 |[4.414367138680041,-10.32624175635328,8.963324308916228] |[0.7941127247055376,-1.321371532702518,1.398892340103383]   |0.7941127247055376|-1.321371532702518 |1.398892340103383  |1         |
# |5.005396944639823|-9.301070062115645|10.35473056351597 |[5.005396944639823,-9.301070062115645,10.35473056351597] |[0.9004347126254749,-1.1901880174546229,1.616046989924021]  |0.9004347126254749|-1.1901880174546229|1.616046989924021  |1         |
# +-----------------+------------------+------------------+---------------------------------------------------------+------------------------------------------------------------+------------------+-------------------+-------------------+----------+
# only showing top 3 rows
