# %% [markdown]
# # Yêu cầu:
# # Yêu cầu:
# 1.download bộ data nhận dạng gương mặt người nổi tiếng từ link: https://drive.google.com/file/d/1kpxjaz3pIMrAhEjm7hJxcBsxKNhfl8t2/view
# 2. Biến mỗi gương mặt thành embedding sử dụng GhostFaceNet
# 3. Dùng Faiss và các embedding thu được để nhận diện gương mặt , áp dụng kĩ thuật Enhancement để tăng hiệu quả.
# 4. Visualize , đánh giá kết quả

# %% [markdown]
# # Using GhostFaceNet - The new SOTA Lightweight Face Recognition

# %%
import os
import cv2
import numpy as np
import pandas as pd
import tensorflow as tf
from tqdm import tqdm
from sklearn.preprocessing import normalize
from sklearn.metrics import roc_curve, auc

gpus = tf.config.experimental.list_physical_devices("GPU")
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
print(gpus)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Copy and Extract Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/LDS8_new_content/b9_face_recognition_p2/data/train.csv train.csv

# %%
# !cp /content/drive/MyDrive/LDS8_new_content/b9_face_recognition_p2/data/train.zip train.zip
# !unzip train.zip -d train
# Out:
# Archive:  train.zip
#    creating: train/train/
#   inflating: train/train/0001ede029cd4018a5470da6624ac253.png
#   inflating: train/train/000dc5578cf64e97b88e30c657083f6e.png
#   inflating: train/train/00210b5b3053449ba58a4656b40ae899.png
#   inflating: train/train/00269d26afcf46859f17f6bf7570a045.png
#   inflating: train/train/002d99a32ad04c13a21d13bf2889c471.png
#   inflating: train/train/003092502e9d4fbaa86f53f335405019.png
#   inflating: train/train/004292adbcae42ba87d35debd0233eef.png
#   inflating: train/train/004a715810774807a7418d1dc6c30e88.png
#   inflating: train/train/004ff50165594dbe8b0292cf881b8abc.png
#   inflating: train/train/00576a695ac84834aafe9d3020edfa7f.png
#   inflating: train/train/0060df6884994a33b3d4b99e7f3792bb.png
#   inflating: train/train/006b81b653374d16ac8e8c5f46e77599.png
#   inflating: train/train/006e585d392e458abb7957581c503342.png
#   inflating: train/train/0074c8fbe4094784b7a91df878fe8ba6.png
#   inflating: train/train/00855f3e0bbd4ca2b991289f5cc8cd77.png
#   inflating: train/train/00924c61296e49639615a4e4ffbc93c6.png
#   inflating: train/train/009997f67d164204a24688b65cff002c.png
#   inflating: train/train/009d1989f52c4e1b9745774e970609a0.png
#   inflating: train/train/00a8d0beff6d46519e4e93970b7688b7.png
#   inflating: train/train/00dc3101a0f443549607d3a1e1e06d47.png
#   inflating: train/train/00ef579e9a38494483580ceda11ffb82.png
#   inflating: train/train/00ff04698e06426eaaddb19384afaefa.png
#   inflating: train/train/01023659118b422e8499b40973042ad4.png
#   inflating: train/train/01091055b0604b07a001fb5cee3bcc86.png
#   inflating: train/train/011fd7e0fc4c406796205834556fe56c.png
#   inflating: train/train/0123edb8e8044a97856e4d20c22a131e.png
#   inflating: train/train/0129b8e713fd431b85405d302d180c60.png
#   inflating: train/train/013760c04ad34b4fac8bdd92470b0adf.png
#   inflating: train/train/0141bfb85fb045d1bcd973cc764d6a88.png
#   inflating: train/train/0144846945e546dd84cd5a939716fd0d.png
#   inflating: train/train/01463de852bd4827922abb9dd5f79f39.png
#   inflating: train/train/0149f8571e06499c88a00b9797c439ac.png
#   inflating: train/train/016a1e674ccc43a981383477d4eab47c.png
#   inflating: train/train/01756c14075e483a82902b8774512806.png
#   inflating: train/train/0177954d561c4121968f6f4c8263847b.png
#   inflating: train/train/018f199790ac47c3886d905e3c3feba8.png
#   inflating: train/train/019e9ea46b0e47668c5e70ae4a44f048.png
#   inflating: train/train/01a271f9ca1049e4ac86f2dd347b4b46.png
#   inflating: train/train/01ae800e2c9b4273bc60deeb015ada5e.png
#   inflating: train/train/01e4a21b7aa34fa285b8c2f36f316fdf.png
#   inflating: train/train/01eb5178fba84f1bb20872f6f1e34cd1.png
#   inflating: train/train/01fdd5bea5074ccdb88136748012ef54.png
#   inflating: train/train/0205d22ba3a84392aa88fc1d2e4f2c73.png
#   inflating: train/train/020dedbdae1b4cdd8bb0c86dc2a4ea45.png
#   inflating: train/train/021975a4808547448e7f77cb2641156b.png
#   inflating: train/train/0224bb97dfeb404c98b5017dd88ed666.png
#   inflating: train/train/02276f9ba1b9415dbc7cbd04bc1fdbe8.png
#   inflating: train/train/022cc2be55ec42049363a19b269bb9fc.png
#   inflating: train/train/02463479cba14a5e82705e79ab963f8c.png
#   inflating: train/train/024658d2c53c41cf99f28e2e514ca719.png
#   inflating: train/train/024d3095c9f14bd784b1eb7dee700037.png
#   inflating: train/train/027d4f97b0c342fca9517ae644ba0343.png
#   inflating: train/train/029caa58e3f146c0b7c3c8e996b8c982.png
#   inflating: train/train/029d78fc64fa429a8d89376d6811bc33.png
#   inflating: train/train/02b8132e57584f0aba0b024ab97fc5f0.png
#   inflating: train/train/02e4c3f3f2964190a73df993d39c55a4.png
#   inflating: train/train/02e7135af7a64b3dabe66ca24eb413dc.png
#   inflating: train/train/0310e3e4619a4d4783e57c5979fe895a.png
#   inflating: train/train/03155c40684d4c69b8981da43ff2fbc2.png
#   inflating: train/train/032c5c0ddd0d4805be8a0a4e7522f46c.png
#   inflating: train/train/03318ce7f048408ebc2ae6f6b87dec96.png
#   inflating: train/train/033d295ddf884256b51a2185699826dc.png
#   inflating: train/train/036086f393444fa5ab678223a4249d03.png
#   inflating: train/train/037737a0bb3d4d4f93b2d10e1c64d667.png
#   inflating: train/train/0379c2c633494ec8b4f651087817fab2.png
#   inflating: train/train/03875249eba3436fbc22c94fe5c3961a.png
#   inflating: train/train/0390ca68e3d8443e9c13d250074043be.png
#   inflating: train/train/03a5766bacfa4d2dbc04fe6d29a4e829.png
#   inflating: train/train/03a864bc805f47ff88d208929981d582.png
#   inflating: train/train/03b377bad6674b34a2844a91f28afe2e.png
#   inflating: train/train/03be6b6167e84d2096f208565e4bfb20.png
#   inflating: train/train/03c5fef32ba84463845a3b10f8219c08.png
#   inflating: train/train/03cd62f155aa4f2c9096be2f46947fae.png
#   inflating: train/train/03da2908ea3840e0809b46cd8076bdd6.png
#   inflating: train/train/03de187928324910af461e391b16feb1.png
#   inflating: train/train/03ee8d5822974cf09be8e0ce162bb182.png
#   inflating: train/train/03f2d68cd9fd4d69a996eb7b3836d9ae.png
#   inflating: train/train/03f3f3fcc82946f2803e3763dea9122c.png
#   inflating: train/train/03fa9120f7e540739322da0164e50da5.png
#   inflating: train/train/040be83f965244a79243b4579cea5702.png
#   inflating: train/train/040eb0a5efbe4f8f96a7e2f4afad9eef.png
#   inflating: train/train/04131741d2134a5eb19e06bad1bca133.png
#   inflating: train/train/0413f0e4c6de4a07ae19ac4102e4b6d9.png
#   inflating: train/train/041a4c30a3be4f45aed2defb95248f2e.png
#   inflating: train/train/041bc30432964f95871d4c223eba8f7c.png
#   inflating: train/train/042032146f0348758b8c539f19e2b8fc.png
#  extracting: train/train/042fed1747ba40ea9e65f26bcd326881.png
#   inflating: train/train/0437461ed96d48f48e2cf928e85d54e8.png
#   inflating: train/train/045983ab29ee493cb3d64f71967c8347.png
#   inflating: train/train/046f525c3edc420c9f9e7303251c3eed.png
#   inflating: train/train/04706a5e4f804b17b85378b7f44e2570.png
#   inflating: train/train/04795be5f1cc4950b1afc32a561dbc65.png
#   inflating: train/train/04c302a7a253467f8a75f4f6d65e6b5c.png
#   inflating: train/train/04d265ffb4d34105834416287c89daae.png
#   inflating: train/train/04f8e7442ada4d16a764566f530277d9.png
#   inflating: train/train/050342d6545f45a4876be42184ef34ec.png
#   inflating: train/train/05194965ed084b5e8a0106049b329a35.png
#   inflating: train/train/05228e6de4c2406a9af8c69668c90660.png
#   inflating: train/train/0544e22f557348ccaeb198405778ec67.png
#   inflating: train/train/05588b18020c425c9d20623e3d3b6094.png
#   inflating: train/train/05707fc26fc541ae9d832b4344f08af1.png
#   inflating: train/train/057a8ecaa312456cbecc87345764de5e.png
#   inflating: train/train/058557860c6e4e60834439f7531663cb.png
#   inflating: train/train/059b98525e6c42bbb3dabdba814a1ba5.png
#   inflating: train/train/05ad6f7f84cc4dafbc0ca2b8ce31782c.png
#   inflating: train/train/05b7a6ff4c77451990505dce4083627f.png
#   inflating: train/train/05bce3e935204c0d8287bef521086af7.png
#   inflating: train/train/05c3334cb2d044e8b609d5f6e0d1b9a8.png
#   inflating: train/train/05ce1fa49386471d87d3224be068daeb.png
#   inflating: train/train/05cf77799af6462a95a7af81ff7a7b19.png
#   inflating: train/train/06079072a25c460a94751c515aa1cc95.png
#   inflating: train/train/061a3b80847b4f4eb4cfdda88adf4b4b.png
#   inflating: train/train/064d8d30ec1d43c8b5402738211adce8.png
#   inflating: train/train/06528c15dac14ab8ad5c96823e9910f2.png
#   inflating: train/train/065a66a01a514377b8f0ae2d3111528b.png
#   inflating: train/train/065c7d9162c34ffbadabf7da815c66dd.png
#   inflating: train/train/06613d2362974abeada4c1e549d48a96.png
#   inflating: train/train/066330f0e4a84f63a0859acf40a1b21b.png
#   inflating: train/train/0668ba3e84e640f19fe5d36b8eb9886d.png
#   inflating: train/train/067300f94a6641078f3a400cc1f286b6.png
#   inflating: train/train/06739fb10ae84cb5a537b45421b5062c.png
#   inflating: train/train/0675afdef6f64017ad3624f47f5d59be.png
#   inflating: train/train/067ad9748caa4386a9d2694376f8c5c7.png
#   inflating: train/train/06902f2581c7468b8750a781f1850d7f.png
#   inflating: train/train/069a56f2d1924fe0bce015d39b4da956.png
#   inflating: train/train/069f8f949c74469f98679daf83113710.png
#   inflating: train/train/06b85eee84644942aace3286871f341f.png
#   inflating: train/train/06bf2187a20045f09395c117d13eaf13.png
#   inflating: train/train/06c4e2e62817420da0f18faef7be216b.png
#   inflating: train/train/06da06c77fec427d85b1f801e41993e5.png
#   inflating: train/train/06de1158b1c54fc5a11d9e533add7cc2.png
#   inflating: train/train/06f1decedce749599f662da29dc20614.png
#   inflating: train/train/06f9ab6ea8d84618b2aa21e76ccf4124.png
#   inflating: train/train/071d1d5013464dca87cf6222ff4e0d8d.png
#   inflating: train/train/07298c59ccfc47c2947d695a19289fa5.png
#   inflating: train/train/073e1eb34f2046ddb86f84b2c1cb3797.png
#   inflating: train/train/0745ff06a8d5404fb97e196918c10c78.png
#   inflating: train/train/0755b7b1c49f4c49b930b76db00f633d.png
#   inflating: train/train/07a2dd93aff64e328f812f51561d550d.png
#   inflating: train/train/07a3c6ca053647c6bfdb0bac9c5a29fb.png
#   inflating: train/train/07a92cb7d5ed489e8b985ef925d64ecc.png
#   inflating: train/train/07ad5570699c421c97389d97f024a83b.png
#   inflating: train/train/07b3ce98570547378cface7eb4572400.png
#   inflating: train/train/07b5d9292846474e9d492461e064b36e.png
#   inflating: train/train/07b8cc59567e46fa9ac5243c11590009.png
#   inflating: train/train/07c195a7e1fd4a0e840515c394dd015d.png
#   inflating: train/train/07eebbcfeb624276b4a4adf1232fc5d7.png
#   inflating: train/train/07f07080cf3941c2a1b1b8d0be7ee4e4.png
#   inflating: train/train/07fc28b665334aabb9b9fe3a60f3e88d.png
#   inflating: train/train/080f682ec8a94911a10cf9e207b35c98.png
#   inflating: train/train/0820b65226a04765812251de1d16fabe.png
#   inflating: train/train/08305df3e5e543e99d4b561fdb46941e.png
#   inflating: train/train/0830f0cae1bc4e2893f8fca999047e05.png
#   inflating: train/train/0838eac646754801bedf834c1ec102a0.png
#   inflating: train/train/083b1406480c4e92aec65f804273cfe1.png
#   inflating: train/train/0842f3f9b0f54dd4a2143df963853d32.png
#   inflating: train/train/0861d569a7ed44fb94d0f91338344ec7.png
#   inflating: train/train/0868500249364876b938a4c9b6e6ba54.png
#   inflating: train/train/0886645f7a4647ebaf0e19ce2ded245c.png
#   inflating: train/train/089c59647bb44a7eb9f14629d90b957c.png
#   inflating: train/train/08a2228e6e3d466097a0cfb9fd3c4096.png
#   inflating: train/train/08cf8c195c0a47bcad269aa9f57e2321.png
#   inflating: train/train/08d6dfcce2334e62877ea78a9c0f9348.png
#   inflating: train/train/08e1bf996219406a8ed32571818f83d9.png
#   inflating: train/train/08e4ef1c64834bfa90e42dd93cafb736.png
#   inflating: train/train/08ed113e06be4372960534182d794838.png
#   inflating: train/train/08f2ba94a6ad4c1995d5a20e0b14ce73.png
#   inflating: train/train/090b7feff6f54ed19ac33230415f89a8.png
#   inflating: train/train/0916f2d0396c426ab92a1bf6eac81630.png
#   inflating: train/train/0917bc21aca345b0b70826d4c6b7b064.png
#   inflating: train/train/091adad820804735998a5505ace00785.png
#   inflating: train/train/093e545f773c4d89be99c7515f9c9394.png
#   inflating: train/train/093eff110822461f98b29a51a78e6da2.png
#   inflating: train/train/09617b5bfd3f45928da7419912d8f1cc.png
#   inflating: train/train/0961d50d0b1044709496a2839cb164fa.png
#   inflating: train/train/096a910270ba419da1282810b4ad2db4.png
#   inflating: train/train/096afe7e1c474d27b1dc495759d823ce.png
#  extracting: train/train/09745cb40f3c4c84b38a7ddb34907aef.png
#   inflating: train/train/098f575b42b14138807f5114e642e699.png
#   inflating: train/train/09ab4ff0ff4945599f0af62a3be0e53c.png
#   inflating: train/train/09abca5cf49d40cf947b97e1a526af0b.png
#   inflating: train/train/09ad8fab35804a2a8eb9cb52e081ce95.png
#   inflating: train/train/09b093a234fa42a6b6f7edc4b5480172.png
#   inflating: train/train/09bcea7199224adaa999295fd9d5a9f7.png
#   inflating: train/train/09cd024154504be19cca073c9749788c.png
#   inflating: train/train/09cdcc87341f4b6cb46696ee386bb417.png
#   inflating: train/train/09d2bc9f6e2d4383a7666ea8d020daad.png
#   inflating: train/train/09f1a1f7a1554de8b53365f40a918891.png
#   inflating: train/train/09f9bd35bcc241719f70a6c3d83d5eab.png
#   inflating: train/train/0a05f854c1fb4f36bae2146f357d4072.png
#   inflating: train/train/0a103dce36424744a44f23d85b3758d7.png
#   inflating: train/train/0a2064df567c428facbecb0eb80c014b.png
#   inflating: train/train/0a20e143d63c478289a46164f512b7c6.png
#   inflating: train/train/0a2a2d60f1d44c9797a203ce108b0e87.png
#   inflating: train/train/0a2c61843f8e4d31b31789023e15655e.png
#   inflating: train/train/0a2ebc03998c442d853396e9be495212.png
#   inflating: train/train/0a3711a8b8d0409596747844c210a159.png
#   inflating: train/train/0a3eb4fa46a248c9a0c074bf5e43d2bf.png
#   inflating: train/train/0a46564b22624b9690eaa6a85cff53b5.png
#   inflating: train/train/0a4a4ef1dd4940b683acb4d05435f619.png
#   inflating: train/train/0a616a478f1d4a25842a142180debbeb.png
#   inflating: train/train/0a61735645964488b00918cf18fb8a71.png
#   inflating: train/train/0a63fa3e40934d7f81399b6510cbc4c1.png
#   inflating: train/train/0a815ca0dddc4d2095be8c6d0025fedc.png
#   inflating: train/train/0a837924845f4802b07d2d124a95cb95.png
#   inflating: train/train/0a938001421b486c9a70a85c60736c4e.png
#   inflating: train/train/0ab290bc6a684712b5f84d61ad3e2a9d.png
#   inflating: train/train/0abf21ec85ad4181b675ba5d8ca8afdb.png
#   inflating: train/train/0ac0a050d0a34b58bd1dd31b0c54f47a.png
#   inflating: train/train/0ad5a3fb36dc4111a43ecdef023a1ed2.png
#   inflating: train/train/0addb24a27414f8e90a191685f4c81be.png
#   inflating: train/train/0b1772cca7d44a4a9c4a5fd2e5403a7e.png
#   inflating: train/train/0b3cc64398424e0f8a8acea801b449ef.png
#   inflating: train/train/0b4466e75a5a431b86d81807977674c3.png
#   inflating: train/train/0b51119754a44395a101488d2be98fbc.png
#   inflating: train/train/0b5e0b5942364dcfa0815026b83d24a3.png
#   inflating: train/train/0b6922d6527b4362b74106182d630e49.png
#   inflating: train/train/0b6d96de8089464284635d340ed56bdf.png
#   inflating: train/train/0b6e6c7c41e742499dd003e534297f07.png
#   inflating: train/train/0b80b43d42b44a4995a877fbb130a645.png
#   inflating: train/train/0b82d022c6b24c41b66f6dde8b75f924.png
#   inflating: train/train/0b895fdf65434786a3d4bdf44b9816b6.png
#   inflating: train/train/0b8df2f7ca524709bc92392790c99496.png
#   inflating: train/train/0b8fb1cee5ff487bac15fa6a50bfc664.png
#   inflating: train/train/0b936407a88049afbaa85afb8ad29d88.png
#   inflating: train/train/0ba744ac509e4e2abdf4f78b73780d72.png
#   inflating: train/train/0baf174a9440407491ca2034b9ea73ad.png
#   inflating: train/train/0bde95f80b0b485b888ffe416da2ca16.png
#   inflating: train/train/0be15fd46ba448a887b4da0297d4a2db.png
#   inflating: train/train/0bfdc02abf2d44efb7bf5a97cd8dc68e.png
#   inflating: train/train/0c18734c439d48b28e46dcec7a3c0a0e.png
#   inflating: train/train/0c1bc4b1ea854c60a8b73a027f1c3693.png
#   inflating: train/train/0c24e786ce3c4b41905d31073fbbd04a.png
#   inflating: train/train/0c2f298effb64ce79d1111c88fc61f83.png
#   inflating: train/train/0c397dc03b1a4c7ea9424d74835e7ac0.png
#   inflating: train/train/0c4913a69a9447f9adc5acbeba64f451.png
#   inflating: train/train/0c4f6f4997524adf858d71fc03765dc8.png
#   inflating: train/train/0c532f50e67e4a60a93944aab306402d.png
#   inflating: train/train/0c53d4ecf12f4b90adac4fe22c275558.png
#   inflating: train/train/0c64561d14dc4a7ab99ff59368f0c092.png
#   inflating: train/train/0c6cd73eae26461397a6057ab3003748.png
#   inflating: train/train/0c6f142d46904e62baae40e08bcd6c2e.png
#   inflating: train/train/0c702f3241424f04b5c82c94a6ff4f71.png
#   inflating: train/train/0ca9025ff97542b6a30031b9c051d7d9.png
#   inflating: train/train/0cb57ddd7d0a4b30b78f0728b47c8609.png
#   inflating: train/train/0cb6a47883f74f6296b6735db4353df0.png
#   inflating: train/train/0cbba2e78fad4c59ac714d84362e03d8.png
#   inflating: train/train/0cd1c163f91a4ebbafe5568753cda703.png
#   inflating: train/train/0ceb7a8b1d124561a5966d4f6900cea8.png
#   inflating: train/train/0cecb3cbbbeb4fb387cb09d367ea1194.png
#   inflating: train/train/0cfb6af2717743d99c12971ea045242a.png
#   inflating: train/train/0d028e79f4624359985e32cad0b017a6.png
#   inflating: train/train/0d0d2ea1c4ce458ebed8af50b6d6ddd5.png
#   inflating: train/train/0d12a18188424ec88b35a47f352a04d5.png
#   inflating: train/train/0d17eea395004e6eb7a15ec9c9818c41.png
#   inflating: train/train/0d1920a08b6f405ea0c895b9bcc9c1a5.png
#   inflating: train/train/0d32f965544f4c528c6bbbfa285f9d6b.png
#   inflating: train/train/0d334c850ee346f293fb6326f29ab063.png
#   inflating: train/train/0d38442e41914bd3b7f7efb3df17f4ee.png
#   inflating: train/train/0d3e0753d60348dca63f986ea4d7074e.png
#   inflating: train/train/0d49acef60f6449794b0b86666c2862c.png
#   inflating: train/train/0d53c7c990f745fabb26c1e5a20388b7.png
#   inflating: train/train/0d56252222b94348978b821c5654a97c.png
#   inflating: train/train/0d5ee46d47fb4bbb8fced0f0da006fa8.png
#   inflating: train/train/0d62c6ddf95b42d8b9e0b7a5a8b2e7db.png
#   inflating: train/train/0d6778bce68a47a3b20b8de6b01eca0c.png
#   inflating: train/train/0d846fa208f04a82bf63042bcfa76fa6.png
#   inflating: train/train/0d9766f6820d42d5a877616493ec629f.png
#   inflating: train/train/0d98cd07934f47858df7ff8e709a3aa1.png
#   inflating: train/train/0daa2d9ad98846b8a9004c9a98f0197a.png
#   inflating: train/train/0dc37df9630148e38e0d6d4abc0a6377.png
#   inflating: train/train/0dd5b95f73024095a1266a978c96c5a7.png
#   inflating: train/train/0dd73080ba2f467c84e32daabffb121f.png
#   inflating: train/train/0df1cfe33d904abeb5567f1a180dbeb1.png
#   inflating: train/train/0dfca5b3447f4b038d8492b4bd793bbd.png
#   inflating: train/train/0e03e40f289047aba2c3aebe36dc8300.png
#   inflating: train/train/0e03e781b86746bc8b4d5dba9f92ef7d.png
#   inflating: train/train/0e1f19d2001d4310a98d68e08b7531a7.png
#   inflating: train/train/0e298f249fcd4593919d4f249bf312c2.png
#   inflating: train/train/0e2af82e24cc4b6385f16ad4b276faa1.png
#   inflating: train/train/0e305cd2eee84dfca9985da288a9a6ba.png
#   inflating: train/train/0e3415d6e3d345f690c0a651c08cdfda.png
#   inflating: train/train/0e342615e90b4501825fd433488a1efa.png
#   inflating: train/train/0e497fc07166469ba0e658b6a4093db8.png
#   inflating: train/train/0e5a795f205c4ed8a4b014dcadfc62c6.png
#   inflating: train/train/0e659116e9634fc39563e464406fd0e8.png
#   inflating: train/train/0e681abd29c8478f8315f9b3ea226b02.png
#   inflating: train/train/0e72edb95e204f6491de94f0cc3ce67b.png
#   inflating: train/train/0ea6c47e910f447984f71d619334de02.png
#   inflating: train/train/0ece360d84454ab9864b74d807f4006e.png
#   inflating: train/train/0ecf4f1a5ff04b018a1de418c2db86a8.png
#   inflating: train/train/0ee043783140449689ebc71c398f7f97.png
#   inflating: train/train/0ee20fed56fc47b7a613b3903a75a016.png
#   inflating: train/train/0ee9d14e9c2146f18db83db4b0a55ace.png
#   inflating: train/train/0ef19498ab974325950e6883f6f2a16e.png
#   inflating: train/train/0ef677e1c2b641b892c183c8851f8d75.png
#   inflating: train/train/0ef86328770d4f228b55522a987aaf82.png
#   inflating: train/train/0efc86297b45468fa2e35e8ab2e792a0.png
#   inflating: train/train/0f0e5c0122a64485a7425974fe205f36.png
#   inflating: train/train/0f1417fc7e2044a68bccee7f95061c91.png
#   inflating: train/train/0f38da0e9d054200ba31404ff2912b55.png
#   inflating: train/train/0f41f9c506cd46f79681052631db3f43.png
#   inflating: train/train/0f50763e350642de94e7962cb476004e.png
#   inflating: train/train/0f53b87e91a24ac68e5fe8bc73171a62.png
#   inflating: train/train/0f5ffaf83f34407387f7400c981a2020.png
#   inflating: train/train/0f7b762301064abf96a71d524b2d1502.png
#   inflating: train/train/0f86e3fa825a4198824bba0774e49b11.png
#   inflating: train/train/0fa72f14e45045dca29b7d69fbb2f9e6.png
#   inflating: train/train/0fb9ac2e8b8e498d916aca44286613dd.png
#   inflating: train/train/0fbd0423c5914451a2b035dfaef85b04.png
#   inflating: train/train/0fbfd42058d14420bfc529dfdf12f270.png
#   inflating: train/train/0fcdea0c781447bcbc9acb9edaff830f.png
#   inflating: train/train/0fcfaabcaee647d8aabc291c0e28e80c.png
#   inflating: train/train/0fd41f74b97748a58c6b09b39829072d.png
#   inflating: train/train/0ff6654c85474cab85eab540f8c94eb9.png
#   inflating: train/train/0ff696a4cf314af8936e159f10087485.png
#   inflating: train/train/1006087a0f034137953b2e45d6efbe6b.png
#   inflating: train/train/10082a00d92d48b1bd7cf42ef023926c.png
#   inflating: train/train/101d281346ef443aa74c8efa67aa0ee6.png
#   inflating: train/train/102a5ecf66ab429aad2279a869397f43.png
#   inflating: train/train/10345de0bb1240dd921296c38f113cac.png
#   inflating: train/train/1048d3d8e2a74bf2bc887df0680003fa.png
#   inflating: train/train/10520a56a8ad4d7ea4d55efa447ced2e.png
#   inflating: train/train/106c9874d8c8480e9d524ecb9559d1f4.png
#   inflating: train/train/106d14acb79746a4a03d8588992af9f4.png
#   inflating: train/train/107b1f40231c47ec96c4d0802b116b87.png
#   inflating: train/train/1089a478f27b467b9e7f3d3f9dcb5e83.png
#   inflating: train/train/109499da636d4528ad5123139269d033.png
#   inflating: train/train/10a9ed5e9f5f44e79dd414f1907a5a66.png
#   inflating: train/train/10b36d309a0c4baeafe312e55355ef47.png
#   inflating: train/train/10b59deba1ba444da6c617a117a22239.png
#   inflating: train/train/10d0e9410d19494cbe8fb97e92e9a77c.png
#   inflating: train/train/10d2422aa61142f79ccd8b32c6101167.png
#   inflating: train/train/10decae48257415c89a26d1ddc8ae7a9.png
#   inflating: train/train/10df7e9cfd9f454e85c711be570f60b9.png
#   inflating: train/train/10ee6311a4004346800a815b23111440.png
#   inflating: train/train/10efec678b474c4bb95b04e13b3299eb.png
#   inflating: train/train/10f5dd412abc485893010b48ee37faad.png
#   inflating: train/train/10f9ea55ec84445182cf6af1ee726207.png
#   inflating: train/train/11182d4624c646af9a8ff78e3ad700bf.png
#   inflating: train/train/11294ed51dc647b48970542a66635759.png
#   inflating: train/train/114599258c6f4be9adeaefe5fe896d39.png
#   inflating: train/train/1149be92eea043a992b5d52ab0de08ff.png
#   inflating: train/train/1152ae4404c44d2498502d0b67ba2bc7.png
#   inflating: train/train/1176a07cf1ca49c48537d2540a9c7286.png
#   inflating: train/train/118f184159814c8bb95de827964f5f3a.png
#   inflating: train/train/119d8ab8e59a43f69c14687cbfd47300.png
#   inflating: train/train/12107b9b18064c77b4a460ff6a6b235c.png
#   inflating: train/train/121445fd2acc4362bd66e4441887d043.png
#   inflating: train/train/121a7594a32f4dbcb72b2a8356dadb03.png
#   inflating: train/train/121d782cd67042adb770455f6684cf45.png
#   inflating: train/train/1224e68d94dd4ae6a996de811e190eb7.png
#   inflating: train/train/1228dc1cadc346409983267fac3543bf.png
#   inflating: train/train/1238500c8276447588fe807a0e3b3863.png
#   inflating: train/train/123e50d832db4d42b67ebd43e97d0705.png
#   inflating: train/train/1244e054777748ab9d32eef9deb80d28.png
#   inflating: train/train/12550741243b47788eaa82a7610c8587.png
#   inflating: train/train/1258882ca6f14478aeff17b855d738a0.png
#   inflating: train/train/12635b4f4a434de9ba663d217dfb84a1.png
#   inflating: train/train/12689c992f6c4df2b4dfc17e73967de7.png
#   inflating: train/train/126fda86928e4a5c8e6f7cb00c7169f1.png
#   inflating: train/train/1274f057c0334e56aa5ea04e35036aba.png
#   inflating: train/train/128a337e7f344763abe41ef822c1888a.png
#   inflating: train/train/1295d784931549688a4eb41e77db1bb9.png
#   inflating: train/train/129868f0e3a54169beeb270180165514.png
#   inflating: train/train/12b26d23f2f84452b349a459059be401.png
#   inflating: train/train/12c052587b074b6fa1afac1e08881952.png
#   inflating: train/train/12c49c54d64b46e5ab86ab20702eec99.png
#   inflating: train/train/12c824e7f00745c5b0e63df1fcc0b696.png
#   inflating: train/train/12c8294df7144832935cd871c3ec6560.png
#   inflating: train/train/12d4775dcd0d4b9cab1498db9bdc5848.png
#   inflating: train/train/1300efdf2a554d60a94ce95cc3ee61cf.png
#   inflating: train/train/130b0a545ef145279147b398300a3ba1.png
#   inflating: train/train/131e864722b94dda9cfdf10e8885260e.png
#   inflating: train/train/1354f87ec6744a53a36f4392fe1bc1d2.png
#   inflating: train/train/13a76f94d8874a4e8bda7a1cfe62a821.png
#   inflating: train/train/13b755bd97654828b51a150a1993ef6e.png
#   inflating: train/train/13b83eb75d3845c28eeca94ec5032243.png
#   inflating: train/train/13c01e5795934ea4836886c6053f486d.png
#   inflating: train/train/13d69c0189dc4e8981e11a1eb5070430.png
#   inflating: train/train/13fe38b4a5d0447e99bcd71b7a3a2ea8.png
#   inflating: train/train/13ff7a2a39254114bee1cc046e9014fd.png
#   inflating: train/train/140309d4ed2446d4a9d26360a24ae7e8.png
#   inflating: train/train/141e29fdb537467a9890084435587810.png
#   inflating: train/train/1422096e1cfd443a9df42599b06ff7a1.png
#   inflating: train/train/1439df1b370c4716907a028f4dde3c4b.png
#   inflating: train/train/143a9bd064ee4c24933149e3f0105d17.png
#   inflating: train/train/1443c921c04247f8b4744470e6cb7427.png
#   inflating: train/train/145b8ac93eda4cedbeb5f9af4775cb32.png
#   inflating: train/train/146d94bdaa974e5e8fb44a526305f7fe.png
#   inflating: train/train/14885e0e20784013a80e18aa25563f38.png
#   inflating: train/train/148c07cdf15d4aa991b2ba44f17e9a49.png
#  extracting: train/train/14a9335e34cd457dbe5bf7c94f9d4475.png
#   inflating: train/train/14c2a675b2244da6ad9f3a25e856a564.png
#   inflating: train/train/14d56b4e48194998b0bad95b6de601f4.png
#   inflating: train/train/14e25bbb4c1d499fae32d0e83dbbb303.png
#   inflating: train/train/1501ee7d135b4a5b92fe0f636f6b1862.png
#   inflating: train/train/150b75c5e2e747dfa25e849276852051.png
#   inflating: train/train/152f61ac4513443dbd337ca12ce78a93.png
#   inflating: train/train/156c5b95a7f4455d9126eaaa8cf6afa7.png
#   inflating: train/train/15768a29a4204085b4042d1de50dc9c7.png
#   inflating: train/train/158ad3db11f0498a81ae4a28098501ab.png
#   inflating: train/train/1599295d38a34d8b9693d7a916c23acb.png
#   inflating: train/train/15b880c4997d441086a32fef01d38556.png
#   inflating: train/train/15b94aef788f49b88decd78ec8f97542.png
#   inflating: train/train/15cbab4809c046f0b1602c788f533fbb.png
#   inflating: train/train/15cc983db7d3457c98e3fbf12a4357a8.png
#   inflating: train/train/15f93370029f4ac596baf76d10765b7c.png
#   inflating: train/train/160c52d1a6724ed89653b35073220e4f.png
#   inflating: train/train/1632f9ef258649fea21bbfe7e6addfa5.png
#   inflating: train/train/164e72f3ca7c48f89d4f674a9887e8e2.png
#   inflating: train/train/165a2db8e48840b4a33fbcd82fbd819b.png
#   inflating: train/train/166171a91bf24b38867af6a2f38bce08.png
#   inflating: train/train/167902b898014e1792089a479b215883.png
#   inflating: train/train/16ad030e98054c5d837f5c0130c1ee62.png
#   inflating: train/train/16adfbb3eada47169af762fa8b0f1237.png
#   inflating: train/train/16b0e781ccb84e4a83e3cf5c6efab238.png
#   inflating: train/train/16eab800cffc45d4b11744a1fa319136.png
#   inflating: train/train/16f9b161400f4b33873133b2b20bf7dc.png
#   inflating: train/train/16fe887adeb640e28acc7c5bc80d5beb.png
#   inflating: train/train/1726410e504f44b386228242caa28d53.png
#   inflating: train/train/173dcbad748b419f8bb66403ef7af01b.png
#   inflating: train/train/174814e9e9e740eab7353c54e6ea8511.png
#   inflating: train/train/174d4d11f0634297b90df92c3c440025.png
#   inflating: train/train/175b4626ce1846c5bc8507f764e1834f.png
#   inflating: train/train/17649033835a49e2a4ac86d399e9757c.png
#   inflating: train/train/1767106b4e184b2da8ab90cf66e3d2b3.png
#   inflating: train/train/1778bbfbbd704e5a8d2b78baf768eabf.png
#   inflating: train/train/177b5d69b41741dfbf35649a94612f7b.png
#   inflating: train/train/177effd937ce42be9ed82c3daeae49a1.png
#   inflating: train/train/1789e9a2a83a42e6a1497fc5f71e60ee.png
#   inflating: train/train/17935c9d63fb4954bba7dc237eb412f3.png
#   inflating: train/train/17a1fd3c489c4362956e0a1395fbffe7.png
#   inflating: train/train/17b3a766aa58437c9744d633b75e061a.png
#   inflating: train/train/17c6b237265d4ad29bc253d05d64f026.png
#   inflating: train/train/17cf7442e4a14a98897ce402fd422086.png
#   inflating: train/train/17dbf642e00f45d682cb0099b5d7e6da.png
#   inflating: train/train/17e97f47f08a4fb98375f02d7dfb7ab9.png
#   inflating: train/train/17ef06514ccc4ddea4a54706b07dac9e.png
#   inflating: train/train/17f84bd4f63f46d9a169b8553bdc30e0.png
#   inflating: train/train/18015785a2764995b0e5026933127589.png
#   inflating: train/train/184954e84406410ab47c121ab2fa9f05.png
#   inflating: train/train/18535aef8e254d3ca91e69613f80e920.png
#   inflating: train/train/186349b0a93b4e028b45a3ef69f84dfb.png
#   inflating: train/train/189d40838fe84b45968f334666d7ad7d.png
#   inflating: train/train/18a7116956c14980bc5afed931e7d36b.png
#   inflating: train/train/18a9eb5522f84fc6819d46a3d67df713.png
#   inflating: train/train/18b217f03ff3442b981d271c8084c3ad.png
#   inflating: train/train/18b654c6c2294c3b801422290dddc636.png
#   inflating: train/train/18be64f1d6024b3caa65b2668d50d866.png
#   inflating: train/train/18c8cc6933df463dad3c4506e688c241.png
#   inflating: train/train/18d2f368513a4abc93122047044aec08.png
#   inflating: train/train/18daf25eb1b44709aca7b37bf6d379d5.png
#   inflating: train/train/18f49cee179e41d78645222d42abae0a.png
#   inflating: train/train/18f872fccd3448938a3b14f4451c4e29.png
#   inflating: train/train/190ad1a2d06e40b8b642e351a87b11d8.png
#   inflating: train/train/19211b915e404b43a5792bd9f13aaa37.png
#   inflating: train/train/19238391d0854368adc860a9c87a027d.png
#   inflating: train/train/192ad749d69e4f8da1612cf31dbfad36.png
#   inflating: train/train/192d00bc527b406f9b88285b9271dd86.png
#   inflating: train/train/193acd370765499290c98690a0ce9e43.png
#   inflating: train/train/193c426e033b49c5b504da00d77186e6.png
#   inflating: train/train/193d12532b284e31805d18178a0687b8.png
#   inflating: train/train/19422768a9c74848993511d346cfe963.png
#   inflating: train/train/1954322b1ac446e2a09dc30d0b5e0b61.png
#   inflating: train/train/19628b049d204a038f0aea6c1ec0325c.png
#   inflating: train/train/196903b77ec64e0fac02e75b530570d7.png
#   inflating: train/train/196c0a96fe2640ccaa23e5b4a28410ac.png
#   inflating: train/train/1974dbbec43b4b2c8e9510e81919bab9.png
#   inflating: train/train/198080fc048d4a50a042411c1de39e0f.png
#   inflating: train/train/19863a5c79fd448db143f1e03a646886.png
#   inflating: train/train/19a5e1d2951040c4a3986f9545ca1cb0.png
#   inflating: train/train/19a87c163e3342f2be99228ae0b1e820.png
#   inflating: train/train/19af97cd24a149128e566cc3abebdc3e.png
#   inflating: train/train/19b10bb2caad4493af3503fb231f99a2.png
#   inflating: train/train/19b9b86d8b21494b85ea8a1f52198b85.png
#   inflating: train/train/19cf5488a5124b22b49104f0ead77831.png
#   inflating: train/train/19f4eaacca534a25a9cb00af5ea8cddc.png
#   inflating: train/train/1a08cf4d934c42ed8c4a53556382a8b6.png
#   inflating: train/train/1a152535ef55433dbdfee8c0eaf1b3c6.png
#   inflating: train/train/1a1ce8c67d044b99be168a8f6656a417.png
#   inflating: train/train/1a27e69105d84683ae8c0fb855c5c89f.png
#   inflating: train/train/1a28571a6fd942019284608445ee0801.png
#   inflating: train/train/1a36e8fecda54926ae0995da41039a01.png
#   inflating: train/train/1a401f2f32fb4acc946c6b7dfe3eedba.png
#   inflating: train/train/1a4c7f53df9448c3a3b32cb664a96a58.png
#   inflating: train/train/1a642b34bbdf4b138d528d6e5bdadc5a.png
#   inflating: train/train/1a64badb49dd4bbf9ded87bd73aafd11.png
#   inflating: train/train/1a7bc96cdbe0441399f4c2be0332402e.png
#   inflating: train/train/1a8b501ac2bb43ba95ae24e360bceb38.png
#   inflating: train/train/1a9585fdb3ed4abea8e6c15e22bb3882.png
#   inflating: train/train/1a9b8471c3104b7eab4d37502b60ed6a.png
#   inflating: train/train/1a9d844b0acf456fa36033fd7bafdbf3.png
#   inflating: train/train/1aa4382019d84ec68f7897a609b45b96.png
#   inflating: train/train/1aa5e2c1bd634a75b82c51dfe950c30a.png
#   inflating: train/train/1acb90dce8904f8ba483a0d93b3b7ff8.png
#   inflating: train/train/1adcc9416b0d41ffa758204591e4f8d1.png
#   inflating: train/train/1ae32571478745e69175d6ed3eab636b.png
#   inflating: train/train/1ae4faf532ba429e90bbb03e7df4768a.png
#   inflating: train/train/1af1fb2ac3504869a15213fada6e9d1e.png
#   inflating: train/train/1af661a3e3274921b7dd0d19714b72fe.png
#   inflating: train/train/1b0d97320b4445c291d46a80dbf549aa.png
#   inflating: train/train/1b169971d041455ca48a23b6d28c185b.png
#   inflating: train/train/1b5e94c969814fc7ba7a425729df5eb8.png
#   inflating: train/train/1b7a4c6716ce467c8a4df71b1c2edfcf.png
#   inflating: train/train/1b7c58cffbbb47fcb51219bcc5e16495.png
#   inflating: train/train/1b97b9d99bb940ceb127093c6e196694.png
#   inflating: train/train/1bb0e1f946d8424d9995c1bcd3943f5d.png
#   inflating: train/train/1bb33cfd5e374ed48c1d6e8ca720e049.png
#   inflating: train/train/1bb6704d636f4a6da583992c06522e4e.png
#   inflating: train/train/1bbd919f75e34c129873e4b61c56fbd0.png
#   inflating: train/train/1bbff9df608441fc9697fc113fc193e5.png
#   inflating: train/train/1bcc196bfde54484b349b0fe62bef2b2.png
#   inflating: train/train/1bd40b7d203140fea4d6fb064bc6a039.png
#   inflating: train/train/1bda4945193c463da8599c66c61370b3.png
#   inflating: train/train/1bf2f2c761fa4a628fe4d9016cb9e464.png
#   inflating: train/train/1bf9fb07bac04aa290d70242faf80fed.png
#   inflating: train/train/1c1053b4ea8f4ff5a14bae3cfb9a5214.png
#   inflating: train/train/1c2334a6b90b45519dea4ba8df24b5bf.png
#   inflating: train/train/1c3300defbf1483b98708515aa651422.png
#   inflating: train/train/1c6de755ac70482a83db35696a64b5f9.png
#   inflating: train/train/1c79f5ab7e054723a3dc329f8f3ddf73.png
#   inflating: train/train/1c8094ef962f4d6e9e2030285fd37462.png
#   inflating: train/train/1c80e7566b4249488bc2ab0450e92eda.png
#   inflating: train/train/1c8df7426fa84ac4bb86c47bba74e1cf.png
#   inflating: train/train/1c8f9235f7a24e34ad6847e341af8571.png
#   inflating: train/train/1c91fe6027f14184ad6a296b2cf37887.png
#   inflating: train/train/1ca9b53ce445438595321a731cef3999.png
#   inflating: train/train/1caa38e5c1ec4252b094f2838c60c053.png
#   inflating: train/train/1caa55f7422f479caa7b678457655cc2.png
#   inflating: train/train/1caa85192772432fa6a9cf9762a0373c.png
#   inflating: train/train/1caccf3ded984dcaa393af9d11876d45.png
#   inflating: train/train/1cc181abeeb84098b71dbc6f843b9cdc.png
#   inflating: train/train/1cd9206eb2214599a1c632dc217084f8.png
#   inflating: train/train/1ce13121b3d446d59d578d4ebf350dba.png
#   inflating: train/train/1ceb395fb6ff4ea1b9389728c57958ed.png
#   inflating: train/train/1cebe6f3e3a048e789efdf2fbcf82177.png
#   inflating: train/train/1ced7b1b0d72497580d3a06dbe6461cd.png
#   inflating: train/train/1cfdd2a53cb54f0bb9f273092148c6cd.png
#   inflating: train/train/1d04dc30d96f430e9d85cb7bffd87d9c.png
#   inflating: train/train/1d1ab9bdb65e4b5bb4fb54f9813b4545.png
#   inflating: train/train/1d2c84b9d55b4901bdc76d05d81d2f86.png
#   inflating: train/train/1d2d95764ec74e6ebc63f41c87439c23.png
#   inflating: train/train/1d3b758c09fe43218ed22ba5fd5cb661.png
#   inflating: train/train/1d3e84d6d8214a888d62f41aa35fdd3b.png
#   inflating: train/train/1d42fb189b3e4fc2b1346e24189c2659.png
#   inflating: train/train/1d591437b8224c90858f44733a8393be.png
#   inflating: train/train/1d64e9d9c381466f810e5961aed11274.png
#   inflating: train/train/1d812620fa094e8eaf474121dc9e8ee7.png
#   inflating: train/train/1d897817ca6949649932c7552beb3b9c.png
#   inflating: train/train/1d8b7e188c4f48c88413c7bf43c02ccd.png
#   inflating: train/train/1d917d4130384230a0d8429b9b5d01b1.png
#   inflating: train/train/1d9e3038798b41609eca05291cbd7e31.png
#   inflating: train/train/1db87cb030024cec8b59635073c4f5b5.png
#   inflating: train/train/1dde0aa3b4004af9a8d14b2c1cb1c6db.png
#   inflating: train/train/1ddea2d4b0524da29afbf8bdc2d09570.png
#   inflating: train/train/1de54aa98a8842658efa6ffb215a0245.png
#   inflating: train/train/1de7a42a0c6d40458b61d9878ff7275d.png
#   inflating: train/train/1dfd61dad5fb43b4ac8f615409e2a28e.png
#   inflating: train/train/1e04470b399f4162a5fe7a3320750e60.png
#   inflating: train/train/1e0c0813d91c4e69b5d675afa3e4e4b1.png
#   inflating: train/train/1e37b92e57ba4a4ab5be2d5ba3d79945.png
#   inflating: train/train/1e3a6b6cf7204d038e9f295117e3c25a.png
#   inflating: train/train/1e3bfac2a7684841bdd6dae35183e3d8.png
#   inflating: train/train/1e4287fa205f4b76a9c8b15ee6064863.png
#   inflating: train/train/1e429666b7c347e49bb0d752c80d416e.png
#   inflating: train/train/1e48899a7e3a491faa62daab52de4a2d.png
#   inflating: train/train/1e6bc33af88d4310914e6a43053756b9.png
#   inflating: train/train/1e71d058a59e41b1a1a2e235c74ee025.png
#   inflating: train/train/1e772f42887c40e7a8596fe634c6d7f7.png
#   inflating: train/train/1e94939aa7cd4679a1670d9b35ba7d7f.png
#   inflating: train/train/1e9af07ce2824b44b327a3d2d70bdea6.png
#   inflating: train/train/1eaae1afa61d44049a05e65e18cdbe0d.png
#   inflating: train/train/1eaf886ab13f42358a8861564277e231.png
#   inflating: train/train/1ec4a3f516cc477e90c66e02730fa5f8.png
#   inflating: train/train/1ec7d92d1e1b4af9aa1d6b524b2be09b.png
#   inflating: train/train/1ed6498f41b544209c5d77ba31c69390.png
#   inflating: train/train/1ed90c8dc3e7493faa7e59b503c7b5ed.png
#   inflating: train/train/1edc224f632b4d918cad0b02c09bb16e.png
#   inflating: train/train/1edf5cb25cfa4a5ea2a4f140189c4c08.png
#   inflating: train/train/1ef5306a732c4855a90f68812a2bae9a.png
#   inflating: train/train/1efc72ea0fbf45a9a521f36a2cf0bcff.png
#   inflating: train/train/1f12c30cdeed47d890c80f1a79933e0c.png
#   inflating: train/train/1f16497726604b70a2e2274108e140c3.png
#   inflating: train/train/1f19fee6371c4f17818c261a339a9600.png
#   inflating: train/train/1f20f6f795e349c7982b81d3e6bcde3e.png
#   inflating: train/train/1f29c84d845342abbc426c347985291d.png
#   inflating: train/train/1f2ab3013b2d4defa509e78d446ac53a.png
#   inflating: train/train/1f4b00708b9f409798c9d42bcca4355a.png
#   inflating: train/train/1f4b6925cb2547a2aeed230f64c7c7c8.png
#   inflating: train/train/1f52031f00784470b7b8e199beee0cd3.png
#   inflating: train/train/1f55c9992f6442d9a3ecb6b5c1407b28.png
#   inflating: train/train/1f59cd1199664b3fb0a0b0356248de02.png
#   inflating: train/train/1f89297554064d3d81cf75e0f368945c.png
#   inflating: train/train/1f8d070477d4404688496329f036733b.png
#   inflating: train/train/1f9796833e3845a6ba87a62b64993304.png
#   inflating: train/train/1fa06fe13ed846a2ac0fe6aafe519ad3.png
#   inflating: train/train/1fa9f639d346409699c93b656f0f7cff.png
#   inflating: train/train/1fb0bb583d8040aa9c3a2e98b3f49e99.png
#   inflating: train/train/1fc411508b0a4c4ead4417dcb8a56dd1.png
#   inflating: train/train/1fc7f498edc9488bb9dd0cbb6f650d04.png
#   inflating: train/train/1fcbb0208a5244c38ad7459a39bdcdee.png
#   inflating: train/train/1fcce7c0595e4c799a9a0a06fa41ef0a.png
#   inflating: train/train/1fdc2ad4716e4dda9d6e46c2499b9de2.png
#   inflating: train/train/1ff98371de4441ad9c55da3466ea0447.png
#   inflating: train/train/1ffab4345c6b47f69a63588bf582d971.png
#   inflating: train/train/200d17a11f5a412ca2b864d9b7f5b06b.png
#   inflating: train/train/2012b788637749d084a15e9a94bfb780.png
#   inflating: train/train/201bf9ef8cac40ab917dfe5640ea3552.png
#   inflating: train/train/203ae247c2874dffa0fb187444f680ea.png
#   inflating: train/train/203c471371ed435bb0ad757e275571b3.png
#   inflating: train/train/204dfe2e10be4857a064d45a854748b7.png
#   inflating: train/train/205ec0010d4e43b3b739465d1a13730a.png
#   inflating: train/train/20869b1a15fc4ebdb0b44783fb652967.png
#   inflating: train/train/208c241c0513413eb90a549a2cef5af1.png
#   inflating: train/train/209654e974c448688cb3d7336c1c0a1f.png
#   inflating: train/train/209def0738564b0fa57cf65f28989089.png
#   inflating: train/train/20a13018508048b7afcae8422b3b6c36.png
#   inflating: train/train/20a35529f12f47e4807930f93b155712.png
#   inflating: train/train/20c44425a8c746708eb11c986534c159.png
#   inflating: train/train/20cc328c7fdf4c1f970a39d5c15fe974.png
#   inflating: train/train/20cfdd327a54478292ac5514cb056b65.png
#   inflating: train/train/20e2ef5c98194da6933c1f0b5b44786b.png
#   inflating: train/train/20f044362f594fc79182996dfbd3c945.png
#   inflating: train/train/20fb990151644f7bb741046e915d115c.png
#   inflating: train/train/20fbf9a54b5f4960aa33684c5d11b317.png
#   inflating: train/train/2101cc4786764209b5bc58e282132a07.png
#   inflating: train/train/2110712e54884b348c425390dd601b1b.png
#   inflating: train/train/211d8395db7a40f39a862a69dd90f9a9.png
#   inflating: train/train/2120b99a846a46b594b66ecf48f12b3e.png
#   inflating: train/train/21261a30dae34ef78ac58db9ff8312f7.png
#   inflating: train/train/212c52ae644d404ca4067b9d9cbc3116.png
#   inflating: train/train/21370c46def94ef783edf8103e948edb.png
#   inflating: train/train/213f85eaa9f8490395bf8677115cfc37.png
#   inflating: train/train/21446ab6e9c74dfcb8389eda719518f1.png
#   inflating: train/train/214ae00d2a644a78a180303019138278.png
#  extracting: train/train/214d3b991dce4788ac5bdb152f89efae.png
#   inflating: train/train/216114d384aa4cb798bfb7689f6c5105.png
#   inflating: train/train/2167667b85554f52988e561b97d129c3.png
#   inflating: train/train/2173c7d1f57b4e57a315b9fabfbecb8b.png
#   inflating: train/train/219d30362f2f4c5f9a0b02d16ebba7db.png
#   inflating: train/train/21cd791b77544a9da29654683dfcb536.png
#   inflating: train/train/21cfde1584654617802dea4e77eefc05.png
#   inflating: train/train/21d01ae9a77b432f92f20ae8d30db53c.png
#   inflating: train/train/21d86fac939843cc8b793dd9e59f74f9.png
#   inflating: train/train/21d87b82fa924af7a83ca9c255f91aed.png
#   inflating: train/train/2202476e60b04d8c98579b37ebcc6bf4.png
#   inflating: train/train/221ddd54f0964a70ac1ac9a44b52e64a.png
#   inflating: train/train/2223bb4fbf494c5197c02948b7948454.png
#   inflating: train/train/222436552ba3470aa76ef4906afa3984.png
#   inflating: train/train/224e6c30c11542e486351ac4036a0998.png
#   inflating: train/train/226b8b1b35254114b57ccd3bda831aac.png
#   inflating: train/train/2293bc706fa74b4bb81cde4c36d63698.png
#   inflating: train/train/22bfcce1307b40039fc4b854ba048a22.png
#   inflating: train/train/22c52a26562049d9a76c0d30b0c96ab6.png
#   inflating: train/train/22d03c69d0b54fae88fe3a309b4e9f1b.png
#   inflating: train/train/22f652cb996e46a19c764f8f9cdb22f2.png
#   inflating: train/train/22f92c551adc4962b87cd53807213f1d.png
#   inflating: train/train/22fa6259125046f580842b3b14785eb4.png
#   inflating: train/train/22fc34af020b403fb8c2293f5296bd9a.png
#   inflating: train/train/23063dd67674476dad895eb88e020229.png
#   inflating: train/train/232242858b0041139b72a803a6301e74.png
#   inflating: train/train/2349a40fc8f748ba91dd79665d5f8c7b.png
#   inflating: train/train/234a521ac1f54f659c8a19bec6a3e60e.png
#   inflating: train/train/234b48bbc31540bcb468e2ed8d8b6284.png
#   inflating: train/train/2351568f360148f3861ffb73d5586e07.png
#   inflating: train/train/236a67d4e97e4106bb081ac757aa2624.png
#   inflating: train/train/23871815922c4cafad3ae9b46abf38ae.png
#   inflating: train/train/23966d6268604bbba2b408c623c188e1.png
#   inflating: train/train/239e7b80989c49d68d6974a22789b00d.png
#   inflating: train/train/23a7624da2c247f08184678d0fe70c9e.png
#   inflating: train/train/23ad01ef7f774d2794d038c83dad8964.png
#   inflating: train/train/23c2c1bb25f7495d9c1891236bd5a4cf.png
#   inflating: train/train/23e4b406a9d24550a6cfb4c8e07a7a1c.png
#   inflating: train/train/23f076e17eb3490d9ff06880212b7915.png
#   inflating: train/train/24028cf252594ffb8bf84bb4a54e8c36.png
#   inflating: train/train/240814143d2d432a99186656f189b7d2.png
#   inflating: train/train/240e820b97394fbd8a0a8f7ee3890f75.png
#   inflating: train/train/241210f416d34fd39fda736223dbb12c.png
#   inflating: train/train/241d03a3f6564aca92a86e2070d4dff7.png
#   inflating: train/train/241e2426474e4b44bf9a6f842247c4d7.png
#   inflating: train/train/2485c56e70d54ee4bdb8bafbb0aec75f.png
#   inflating: train/train/248feff8996a4244a0da3d4f676db130.png
#   inflating: train/train/24990314364741f99680a78d693f2416.png
#   inflating: train/train/24bf4e543ad247f38cafb8129b586e34.png
#   inflating: train/train/24c761a6249449f99512692640fc426a.png
#   inflating: train/train/24c7e1c1bc064ee89ed45399d9accb2f.png
#   inflating: train/train/24c8c3e4e2d9446da87eb680b38782d1.png
#   inflating: train/train/24f33a7915f144dea4da4621e72e7200.png
#   inflating: train/train/24f40caea5fb478a87d05a9fc395a945.png
#   inflating: train/train/24f66af9562f4f8f89d021877c11de8d.png
#   inflating: train/train/24f71319a94b45169ea0b3849e238451.png
#   inflating: train/train/24f7a0a381e24053b8a1c631ae66aaa8.png
#   inflating: train/train/25103d29de4e429ab72bc37a715d01ee.png
#   inflating: train/train/25148fb9e85e44aa9eafa0ebdccd5b34.png
#   inflating: train/train/252de15753d2414e9af35287441d3b3f.png
#   inflating: train/train/252f76c4077a48ae8763704e9a904a13.png
#   inflating: train/train/252faeba0b7b4e6e97d9be136a1f047c.png
#   inflating: train/train/253d536c345a4694a27b3bca53a25a9f.png
#   inflating: train/train/2566ea47bac24bdda21f85354796291b.png
#   inflating: train/train/256dda4bd4d3499da0eb1997b005a44e.png
#   inflating: train/train/2573bbb43672466e93a5d220245c1b68.png
#   inflating: train/train/2584589e5bfb420dad090c9c3800394f.png
#   inflating: train/train/258509e5323c438080e5ea340cfffebf.png
#   inflating: train/train/258f46dff57648dab62b14773c436f3f.png
#   inflating: train/train/259318701f6047439cb4dc9cdc640a79.png
#   inflating: train/train/259409e656364e4d8518d1f2f57caf77.png
#   inflating: train/train/259fa74d51dc459b82b6db70f679f5e1.png
#   inflating: train/train/25a324bc920943f9ade6ffb640ae4085.png
#   inflating: train/train/25b0b0cba3384678b1402388a9e6c582.png
#   inflating: train/train/25c0536982504c8cbf16d0fde35182f0.png
#   inflating: train/train/25db5784dc564bf793a1517e774386ae.png
#   inflating: train/train/25e4d5469300407a9959f36ed51672d7.png
#   inflating: train/train/25ed4747e32640b99c48863d977d8866.png
#   inflating: train/train/25f118e5ff4c438b92d9af074f974467.png
#   inflating: train/train/260173a1a9ba4474a0bcbe066d47c93b.png
#   inflating: train/train/2613a80cbd8d486ea339128527bdcd95.png
#   inflating: train/train/266fc510bcbb46fc928534387884d624.png
#   inflating: train/train/268e769d11614117905cd9ea82cea908.png
#   inflating: train/train/269ca6390e7e4065a99c52a3b4ffa5ee.png
#   inflating: train/train/26bbadcc79514f32bd2c83b953641216.png
#   inflating: train/train/26bdf00a73ad4338a1a006bc055f68cf.png
#   inflating: train/train/26be4f7e8870444fba0a5cef95ff8498.png
#   inflating: train/train/26d7c5ee096747fa8d7b4b294b3ed3d1.png
#   inflating: train/train/26d81455ed344afca7842956f37f515e.png
#   inflating: train/train/271144d6d2004d66bba0a1c331d2b7ae.png
#   inflating: train/train/2737998363894f969f8fcd0cc1596bf7.png
#   inflating: train/train/274d2fae2aa544d49e5aec9d1f0fe21a.png
#   inflating: train/train/27648a17b50047c494650ee843e71543.png
#   inflating: train/train/277b5132d5cc429f81f3174c1b578f96.png
#   inflating: train/train/277d38f9d4ed4efda8dfe74359168234.png
#   inflating: train/train/2793b69c181b4b22914659c677a7ec3e.png
#   inflating: train/train/279ba26e72914f44a9d1ebbc91a4bf9a.png
#   inflating: train/train/27d70cd10a704816809f4b7f12040297.png
#   inflating: train/train/27e2c5a4369d4daa88844029b6e52b79.png
#   inflating: train/train/283bdeae5e3c4fce893073b147b96204.png
#   inflating: train/train/283c3f87643946f4b2c23c05b12cc110.png
#   inflating: train/train/283cce24b1f145deaebce8a1e60c039e.png
#   inflating: train/train/2846f83be3cb4220ae3c56fa42780c64.png
#   inflating: train/train/2872370af8fa438384d1fc8e55cf8540.png
#   inflating: train/train/2889188e56d647cfa7897b92a330d04d.png
#   inflating: train/train/28b0437c17ea482dadcb64c93a522237.png
#   inflating: train/train/28cf9b9be7d84bfb877ed9d86eb8d57a.png
#   inflating: train/train/28d55608f8664116a06cc2749293a5df.png
#   inflating: train/train/28de1d0d71be40cfb991f06ddd161c17.png
#   inflating: train/train/28eef64f78004eca8c9a0fe4276f7172.png
#   inflating: train/train/28fdee26000c47bd942f47f2642d7ec9.png
#   inflating: train/train/2900f0bc8d0641a6ae7d7bc0445750e3.png
#   inflating: train/train/290c19f44bbb4d898842d452abf85183.png
# ...
#   inflating: train/train/f25bb58daca64ba89b7e855685051713.png
#   inflating: train/train/f25c6497d80545f389d43af68f719fd1.png
#   inflating: train/train/f26bfc5e742d42dba39ee80cca722a5c.png
#   inflating: train/train/f271456fc8de4149bfc110d90bf23dc0.png
#   inflating: train/train/f285984caecd43228b8969490b92a9b8.png
#   inflating: train/train/f288538ecae74bc9b1ca9f7d9c44c783.png
#   inflating: train/train/f29669f757e44a5caf4ed0bdb3940f4c.png
#   inflating: train/train/f2af0cdc6cc549e48ce60d8b4ee8c320.png
#   inflating: train/train/f2b960c770a84b4a955090575adea951.png
#   inflating: train/train/f2c1598453f9405382129e0ccda8a083.png
#   inflating: train/train/f2c3a1483ccd402485e600b4aacc2b2c.png
#   inflating: train/train/f2d96445c6204890a49a23cf09a3c189.png
#   inflating: train/train/f2dc044139334523a77b69d00453a59c.png
#   inflating: train/train/f2e5653c70de44619d1224edd591c386.png
#   inflating: train/train/f30af85ba87443a3a06ff1cd296b9de9.png
#   inflating: train/train/f322802f400944b1869d9ec679e1da73.png
#   inflating: train/train/f32adadf304640128563c16267174d66.png
#   inflating: train/train/f3326a2873364247a4d1f843a8bd7b40.png
#   inflating: train/train/f341accbd0d54319b90fbaa73d10f5ab.png
#   inflating: train/train/f344f816257d474285635d58b053b532.png
#   inflating: train/train/f3552f1831e145869b9b19e17ce7b674.png
#   inflating: train/train/f35b591b2a2e4a5f8bc0d2ab1bc419cf.png
#   inflating: train/train/f3769739f9b24d29bc3b75345160cd55.png
#   inflating: train/train/f382adc6b74b4f89b5fcd28eabc1d470.png
#   inflating: train/train/f38c509704fd4c8aa4a8d416839fdb85.png
#   inflating: train/train/f38c6c98dfcd46e3881efff6c4964d78.png
#   inflating: train/train/f395f2305c2b4b18afb669809d1818cf.png
#   inflating: train/train/f3c4760e255941a2b05f6da5279bdb34.png
#   inflating: train/train/f3cbfee015ba491f87e3c616c7f00cdd.png
#   inflating: train/train/f3cc056eef844d1186b83c9c43453d56.png
#   inflating: train/train/f3cf1cba52f54af580e8de54d732a9ac.png
#   inflating: train/train/f3d8f687172f45cea9d89b6cc3f281a5.png
#   inflating: train/train/f3e0355312864ad1912bd77d613b0ac6.png
#   inflating: train/train/f3e1e806655946a6837d275e1efa93c0.png
#   inflating: train/train/f3f78d0026d44667835c2a330b99b88a.png
#   inflating: train/train/f402e139ce004c41a3ebfa00a973a4d9.png
#   inflating: train/train/f42e08b92e3f4bc98508bc8de539bcb5.png
#   inflating: train/train/f4449d801cad4c04a77ac2722c43d477.png
#   inflating: train/train/f492db7bfa1848ee9a44e32aa9cf54f9.png
#   inflating: train/train/f49d6d91a6fd45da8856e925241f115f.png
#   inflating: train/train/f49e988fa4d143f0b527639aa4b538f9.png
#   inflating: train/train/f4a213f5e8784e2db6b22cd9aef169d4.png
#   inflating: train/train/f4a5e38374514d9794d640cb92b8c48b.png
#   inflating: train/train/f4a91719c37e4052902445fc72430323.png
#   inflating: train/train/f4ac8892612f4dc28ccbd49eab7ff238.png
#   inflating: train/train/f4af13ef36674e79bff83a0e72ab102d.png
#   inflating: train/train/f4c78d18701e4975819077decd7cc135.png
#   inflating: train/train/f4cfacae1b894604bcf4072ca30215f4.png
#   inflating: train/train/f4e02703b70e4db3ad8eb83d59471669.png
#   inflating: train/train/f4ec59d14c1a450e806d8916cb5ead87.png
#   inflating: train/train/f4f1835477364ab480a28a94ee414d96.png
#   inflating: train/train/f5209273ea264296b430ae1451c85e06.png
#   inflating: train/train/f534b7847e9543abb2e63399319e3a54.png
#   inflating: train/train/f53b4149ad8044d2a92c731bc3a2887b.png
#   inflating: train/train/f53e02e311dc43358372545f70d5e578.png
#   inflating: train/train/f574d5449a124b4ab33b7d457ad25d5f.png
#   inflating: train/train/f577f85614ec4097b22da1c0a64aa845.png
#   inflating: train/train/f5850cf1f2f944eebc22ff0131caa6b4.png
#   inflating: train/train/f5a7ea6042c044a0a235db3ed3b43c88.png
#   inflating: train/train/f5e4aedd745741ab9ccf2bb7c2127b9e.png
#   inflating: train/train/f5e680c03b07497f9b4ad27bbb3ae9a5.png
#   inflating: train/train/f5e71082345f46e6917a782feb46ec1b.png
#   inflating: train/train/f5eb2b9fbcbb473a9ede3b216d7af149.png
#   inflating: train/train/f5eda318efd74f1c930b562eef1e36b5.png
#   inflating: train/train/f5f25109911e4edea5ac92bdf1042be3.png
#   inflating: train/train/f6109f2299b44c728086531464bdf3a1.png
#   inflating: train/train/f61589ebc7824f31b43ff46295e7f532.png
#   inflating: train/train/f62e2f701f604e3c91a62c3de4e70b29.png
#   inflating: train/train/f62ed95575c043528ed33b4c9e890365.png
#   inflating: train/train/f633859de29144a983a752a335c0ac81.png
#   inflating: train/train/f643fe14ee8f403e91e64c9364c609ae.png
#   inflating: train/train/f6461fad707e4d689d609a29aa89e4ce.png
#   inflating: train/train/f650c01f05ff456da1e1dd39089ec5a7.png
#   inflating: train/train/f65363452bcb4b78b721b806bc3da7d0.png
#   inflating: train/train/f6546195de0e4f75b9073cbe828caf17.png
#   inflating: train/train/f670b10fb73a44fe82e72dfd23da82ce.png
#   inflating: train/train/f6768386d5224a56aa33e93f4d941ceb.png
#   inflating: train/train/f68c5c3031104f57a94d6fae1d749542.png
#   inflating: train/train/f6ad8ae1cc0640218a25db4fce25f02a.png
#   inflating: train/train/f6b3af3672ab4e2daf1e5438a5400396.png
#   inflating: train/train/f6be5367c1ce442385bf6029a0502a88.png
#   inflating: train/train/f6f87b46efce4a5fb8c9dbe235da7e51.png
#   inflating: train/train/f7195c00071740c283d61799535b33f1.png
#   inflating: train/train/f7199d6a7a264aab8e7d3913e62ece31.png
#   inflating: train/train/f72920fcff6047ef91108ca71658c6ba.png
#   inflating: train/train/f733c2cff9b94ef789032818874aeb3e.png
#   inflating: train/train/f77d3c5ff88a4ac8b932a29a333bf12c.png
#   inflating: train/train/f77d8bc682ed42b2b226c9a55c21e453.png
#   inflating: train/train/f78235646aa348beb31ad87641104fe9.png
#   inflating: train/train/f78d95d7346f47b4a599d248121d01d5.png
#   inflating: train/train/f79bc395415c4578a2033196a512f96a.png
#   inflating: train/train/f7b00b030f494d76bc1eac71e10f1175.png
#   inflating: train/train/f7c271e8850c44299b10ca26e5cb2a14.png
#   inflating: train/train/f7cf681b759041d58515342a61cf094b.png
#   inflating: train/train/f7f4cb3d2d6248a8ada4ba24244d8623.png
#   inflating: train/train/f80fa817ff314ec5914d83e3e839fdcd.png
#   inflating: train/train/f818fc5521544c69a3d978968c31177b.png
#   inflating: train/train/f81be802c1a748c394b44169f5868cf5.png
#   inflating: train/train/f824f50793264c2baf0970892b38435a.png
#   inflating: train/train/f8399802dca74203adcc30facb756781.png
#   inflating: train/train/f8424aaa53534a0ab9739cd8267aa9b2.png
#   inflating: train/train/f84537a203c7418e9902bd3fc84e0e1c.png
#   inflating: train/train/f8551183f89b482fb6fb71a12f627097.png
#   inflating: train/train/f85e9079469f4aadb26846da5d7bac40.png
#   inflating: train/train/f8656f2361b840df83620e16d7abb76c.png
#   inflating: train/train/f87a1ba09109440ea68bf9accf49bdff.png
#   inflating: train/train/f8a083d41a7445debb6a20ab4154521c.png
#   inflating: train/train/f8ae5f724dc54428b0ada30b2ff34b79.png
#   inflating: train/train/f8c3dd381ad24b2d9b24d430989281b3.png
#   inflating: train/train/f8f11defba4643b2a4aae7ce75ba70d1.png
#   inflating: train/train/f906a15f46c84bc695383afb3337b7f5.png
#   inflating: train/train/f90705d617764d8d99ab76f0ee9d5a6a.png
#   inflating: train/train/f93b5c09cae84d1bb389b521043de524.png
#   inflating: train/train/f968c4898e52482183e5f4b557d5f17d.png
#   inflating: train/train/f96d3ce9f39244ecb2ab6032b059157d.png
#   inflating: train/train/f9942aa9195f4254b4fbf0a0ca23fcdc.png
#   inflating: train/train/f9954ec3dff6425ea9a3cde6e40397f8.png
#   inflating: train/train/f99a69cd7bda4fc3bbc56e613925a146.png
#   inflating: train/train/f9a044d998314ab1b3a581d0e4120bf2.png
#   inflating: train/train/f9aa37cc86364fefa980ce9be213a5bb.png
#   inflating: train/train/f9ad0ea3905f49409b51c8084d81f188.png
#   inflating: train/train/f9b0ab7bf6774086a6cbe140dc6e5bfa.png
#   inflating: train/train/f9dccc26a96846b5b052993e42a903fd.png
#   inflating: train/train/f9dd8dfd103840cbb6aacd5ba91c401b.png
#   inflating: train/train/f9e6eb7b35ba404f9d2a6bfa4f26396d.png
#   inflating: train/train/f9ee1afcf92d4f9285d66503ec838bd1.png
#   inflating: train/train/f9f61a98172845a19e00fce564bba050.png
#   inflating: train/train/f9fbf0553e0249ed8dfffc5fd35d534d.png
#   inflating: train/train/fa0d1ca0ec3e49029002e05fbe64d01b.png
#   inflating: train/train/fa13b834b5604b189e5821d1b1ed5a9d.png
#   inflating: train/train/fa157f19e5de414bbea0179b3b5cec84.png
#   inflating: train/train/fa235abbd4d0411f8af2466da38d09e3.png
#   inflating: train/train/fa31a34350cf465d8ae662e0dcba58f7.png
#   inflating: train/train/fa32901c95a8467abe48f499f73cc619.png
#   inflating: train/train/fa4aa9989f8b42768c592627ff896c65.png
#   inflating: train/train/fa4b90b1131a4a7298f4104626ad2aad.png
#   inflating: train/train/fa5617fb880348a088790c712fae03bd.png
#   inflating: train/train/fa5776776f9442efb0f11b4a49dbf96f.png
#   inflating: train/train/fa5e98ab7891492a9aae1a9bfe269c3f.png
#   inflating: train/train/fa766fef4d6a4bea91bcad5916707e45.png
#   inflating: train/train/fa8592a767d74c31adcab65a91e9827c.png
#   inflating: train/train/fa9117342751452880b3518f679b1639.png
#   inflating: train/train/fa9adbf419a749ec8632b2e341676f27.png
#   inflating: train/train/fab7c9d0c3b649fcbef10edf30895170.png
#   inflating: train/train/fabbd5e42d7742a6bf84fe2957fadad6.png
#   inflating: train/train/fad344bc4b95451c8958f4ce74564053.png
#   inflating: train/train/faef002b42ed494eae353194b45ea583.png
#   inflating: train/train/faf57cf301dd4ddcb7f19aaa0a61213f.png
#   inflating: train/train/faf999474b7542b7b81a692728dff23d.png
#   inflating: train/train/fb10356eb83a4de0aebc191cb266514b.png
#   inflating: train/train/fb4cca07ec3a43eb82ce12350432e90b.png
#   inflating: train/train/fb6051adf4fc48489e7a91111ec24fdc.png
#   inflating: train/train/fb66bc05d34448d3afb0c175f477b53d.png
#   inflating: train/train/fb6b50bcda744e87bd88897e1d5c5035.png
#   inflating: train/train/fb6fc906bc8a498dae5ee64009be5c90.png
#   inflating: train/train/fb7827f8e4034f7c965c9b6b58051128.png
#   inflating: train/train/fb7e9e280d0744a5a6b27971de757525.png
#   inflating: train/train/fb8f216769904b19ad7ff19b268d003b.png
#   inflating: train/train/fbcb830fe4ce47dcacaf03a7ab75413d.png
#   inflating: train/train/fbd6fa2eb38444e488654670954c6645.png
#   inflating: train/train/fbdd15ecee9e42c6ba3d60db698ef8de.png
#   inflating: train/train/fc023405ee354bb0973a29391d0ff0c0.png
#   inflating: train/train/fc03b1695487463fa91c42cffbb4f5f1.png
#   inflating: train/train/fc04bc0969a54cfb9c2d67c765d879eb.png
#   inflating: train/train/fc0ba91203914971a940c20009edb3cf.png
#   inflating: train/train/fc0f11ce866d43699aa4cc67bf0a57e0.png
#   inflating: train/train/fc1795371eb941508ce54672f905e765.png
#   inflating: train/train/fc2129703771451d996945dee551db21.png
#   inflating: train/train/fc28e5c8c4964204a06b1346b55137e6.png
#   inflating: train/train/fc2acbdd7fa54fc1910b0f3be2abd894.png
#   inflating: train/train/fc34b11fc9284d24af932b96864820c8.png
#   inflating: train/train/fc44e63947b24497bdef52d32a707952.png
#   inflating: train/train/fc4a2ca3a41b41ab9160bec9b0263c9f.png
#   inflating: train/train/fc4f17cb78c249c78f541be1f0afe2fa.png
#   inflating: train/train/fc4fb2da10514c7b9c9366de5c30d932.png
#   inflating: train/train/fc5853d7c46649e796c688b42f2bcfe6.png
#   inflating: train/train/fc678202fe65405487e3c164601702b7.png
#   inflating: train/train/fc6c3fb845ed41cab2a2ab6631c4d583.png
#   inflating: train/train/fc70e1a82e1143fbaab2f4f95e985082.png
#   inflating: train/train/fc81ac6b274241d085a6d045eb03f950.png
#   inflating: train/train/fc98d375a0ad4868b1ef4e5b5e387d86.png
#   inflating: train/train/fc9a860a9dea4f5db6441b2b283318f1.png
#   inflating: train/train/fca0ad3e7e7541248a37ac4296a02002.png
#   inflating: train/train/fca474d6bdf54e9ba7e5129cd70750be.png
#   inflating: train/train/fcb71c2abb6f40fda639742648c47101.png
#   inflating: train/train/fcbe7a1947be41f396bf5f4d0d67460c.png
#   inflating: train/train/fccc43bcd15243eb90bb72bc505bc8b3.png
#   inflating: train/train/fcce23ce61914a2dbed30cce4e099581.png
#   inflating: train/train/fccfcbc1cd5f47c0bb0e5c27c4ba82ba.png
#   inflating: train/train/fcd866874019418591fb79f4d4d555cc.png
#   inflating: train/train/fcd8974338b1409b9dfdbaf637a6dff9.png
#   inflating: train/train/fcdc004befb04586b286e2e78c59bd0e.png
#   inflating: train/train/fcf7e29a749d42b2abc9b3611367117f.png
#   inflating: train/train/fcfae80cb665455f90f640570d9fb76b.png
#   inflating: train/train/fcfe8194f8cd417b8c9e97e5224f7a48.png
#   inflating: train/train/fd068b1d8e4f409980e80989a97a2f80.png
#   inflating: train/train/fd45b36698d84441a6e6de9e4af6fcd1.png
#   inflating: train/train/fd574f0146ea445bbf33fab11cdd8b2d.png
#   inflating: train/train/fd6296f6b4ca4d63b3cca3368d4dcb90.png
#   inflating: train/train/fd6412996e274dee9e50ffaed5f1397c.png
#   inflating: train/train/fd672373e2734a7c8318457ed90e66af.png
#   inflating: train/train/fd8bcd20098e4af08a0b4bfb7b363e33.png
#   inflating: train/train/fd8cd216f8ea49fab90af1fe2db2e41b.png
#   inflating: train/train/fd8e539e64e64c0eaba5631fd1675382.png
#   inflating: train/train/fd926107f3e24fdcbd011e3137f731e8.png
#   inflating: train/train/fd93787fb441424d877c86832c1a8018.png
#   inflating: train/train/fd9656653a0347ecb40293a9abfb2ea3.png
#   inflating: train/train/fda9568374a34a54b69334704d98a740.png
#   inflating: train/train/fdbab72103d741f98a99a843b558b936.png
#   inflating: train/train/fdcf08ed3bc6422e99eefe589177fa2a.png
#   inflating: train/train/fdd8080014324f0eb2b8ba76c5a75195.png
#   inflating: train/train/fde91ed2faee4b42948a8f6d3216a6f6.png
#   inflating: train/train/fe107655b97d42a3aa6a61ff2ed80cd0.png
#   inflating: train/train/fe111b2d43034288a56afa1538c2bfe2.png
#   inflating: train/train/fe23fbc89a864d0c907541d2a871bba9.png
#   inflating: train/train/fe2fa4f2e8f64eefb193c19956539828.png
#   inflating: train/train/fe353b6af94943d29362118132199682.png
#   inflating: train/train/fe59317398a34609a19899bf7ac0b04d.png
#   inflating: train/train/fe6598054adb49dd8af012358b1e1bee.png
#   inflating: train/train/fe7e9310738547228b7bd0b4c5f154ab.png
#   inflating: train/train/fe8bf70609954150bc5985d0bf218e4a.png
#   inflating: train/train/fe905c354b2f498db466849245bdea87.png
#   inflating: train/train/fe9291b705e64b41bab0aa0cda5643a7.png
#   inflating: train/train/febb00061f574fe6a7b4c0fc67ab087a.png
#   inflating: train/train/fed15c3a2dee466796e394987167eca7.png
#   inflating: train/train/fed5cdd7f94d42408b57ea9b3562e3b5.png
#   inflating: train/train/fede0cd8df8742939b6ef500da59f80e.png
#   inflating: train/train/fee79e23cee649f59fabf5454789b075.png
#   inflating: train/train/fef529f8190d46338815f9b00342ebd7.png
#   inflating: train/train/ff00d7a2e9d248759be051cc9a486a84.png
#   inflating: train/train/ff05d4e58c4849c685128d47f127abf3.png
#   inflating: train/train/ff145c5e54184835b023c645df5fd741.png
#   inflating: train/train/ff1ad1bc7b564f669279e6d5e9efe060.png
#   inflating: train/train/ff4cdcd3da9c4f26ab23c7cf2276e0fc.png
#   inflating: train/train/ff698d43887946599d264ca010e038c2.png
#   inflating: train/train/ff7ea2be1ea44525b4d167ff20a96995.png
#   inflating: train/train/ff7f46340b144ba5a74bb56487075102.png
#   inflating: train/train/ff88d0532adb4618b431fc3d7bcb8f10.png
#   inflating: train/train/ff890f85a4e448cdb388417cb1af4258.png
#   inflating: train/train/ff8ae4327aa84d0da2320b9036211e9a.png
#   inflating: train/train/ff999b1b453f44b1b29612384a8929fd.png
#   inflating: train/train/ffb63c6a9d4e4d5cb2c38fd60bc7d253.png
#   inflating: train/train/ffb85dac8cf04b948ba348b0c3078bee.png
#   inflating: train/train/ffbb2d0d3d684b6ca9f54fa6f63c801a.png
#   inflating: train/train/ffc004b1644f4bf988b8e63cd9f6ceb3.png
#   inflating: train/train/ffc598284add4fc78322d3154569816f.png
#   inflating: train/train/ffe9f5922c0c4ca5b53a5be6c76e565a.png
#   inflating: train/train/ffede3446d7445c49739683aa318efb2.png
#   inflating: train/train/ffeeb4369b7f4bcbb28ee88f492b1581.png
#   inflating: train/train/fff7018314da45fca797adb451df5eb7.png

# %% [markdown]
# # 1. Giải thích Eval_Image Class:
# ## 1.1. Hàm init:
#
# model_interf : là model hoặc file checkpoint lưu model và weight.
#
#
# ```
#  self.model_interf = lambda imms: model((imms - 127.5) * 0.0078125).numpy()
# ```
# => Chuẩn hoá input đầu vào
#
# img_path: thư mục chứa folder của các ảnh gương mặt
#
# output_dir: path lưu file embeddings của tập dataset hiện tại
#
# ## 1.2 Hàm prepare_image_and_embedding:
#
# Có nhiệm vụ lưu mỗi hình ảnh trong dataset thành 1 vector embedding
#
# Dataset có 4720 hình ảnh => lưu 4720 vector embedding vào 1 file .npz.
#
# Ngoài ra file npz này còn lưu thêm thông tin tên các ảnh, và nhãn (identity) của từng ảnh
#
# ## 1.3. Hàm do_evaluationn:
#
# Tính độ chính xác của model (accuracy) và, trả về:
#
# labels: tất cả dự đoán của model, ở dạng 1 và 0. Positive prediction (=1) nghĩa là model dự đoán ảnh này thuộc identity đó, ngược lại là 0.
#
# scores: similary (điểm số của model) khi đưa ra các quyết định như trên
#
# => labels và scores sẽ dùng để vẽ auc-roc curve

# %%
class Eval_image:
    def __init__(self, model_interf, img_path, output_dir,root_img_path):

        if isinstance(model_interf, str) and model_interf.endswith("h5"):
            model = tf.keras.models.load_model(model_interf)
            self.model_interf = lambda imms: model((imms - 127.5) * 0.0078125).numpy()
        else:
            self.model_interf = model_interf
        self.dist_func = lambda aa, bb: np.dot(aa, bb) # hàm tính khoảng cách giữa 2 vector
        self.output_dir = output_dir
        self.img_path = img_path
        print('begin serving')
        self.root_path = root_img_path
        self.embs, self.imm_classes, self.filenames = self.prepare_image_and_embedding(self.img_path, self.output_dir)

    def prepare_image_and_embedding(self, img_folder, output_dir):
        save_embeddings = output_dir
        # kiểm tra đường dẫn, nếu đã lưu các embedding vector vào file npz thì chỉ load lại
        if save_embeddings and os.path.exists(save_embeddings):
            print(">>>> Reloading from backup:", save_embeddings)
            aa = np.load(save_embeddings)
            embs, imm_classes, names = aa["embs"], aa["imm_classes"], aa["filenames"]
            embs, img_classes = embs.astype("float32"), imm_classes.astype("int")
        else:
            # chưa lưu => đọc mỗi hình
            img_shape = (112, 112)
            imgs = pd.read_csv('./train.csv')['image'].tolist() # danh sách tên các hình
            labels = pd.read_csv('./train.csv')['label'].tolist() # danh sách label của các hình
            embs = [] # list of embeddings
            img_classes = [] # list nhãn của mỗi hình (mỗi vector embedding)
            names = [] # list lưu tên file của mỗi hình
            for i,img_path in enumerate(tqdm(imgs)):
                img_path = os.path.join(self.root_path,img_path) # đọc file từng ảnh
                img = cv2.imread(img_path)
                img = cv2.resize(img, img_shape, interpolation=cv2.INTER_AREA)
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                img = np.expand_dims(img, axis=0) # biến ảnh về kích thước (1,112,112,3)

                emb = self.model_interf(img) # lưu vector embedding
                emb = normalize(np.array(emb).astype("float32"))[0] # chuẩn hoá 1 vector theo L2 norm
                img_class = int(labels[i]) # nhãn của ảnh hiện tại
                img_classes.append(img_class) # lưu nhãn của ảnh hiện tại
                embs.append(emb) # lưu vector embedding của ảnh hiện tại
                filename = os.path.basename(img_path) # lấy filename (dạng abc.xyz)
                names.append(filename) # lưu filename của ảnh hiện tại
            # lưu tất cả thông tin trên vào 1 file npy
            np.savez(output_dir, embs=embs, imm_classes=img_classes, filenames=names)
            print("file chứa 4720 vector được save tại")
        return np.array(embs),np.array(img_classes),np.array(names)


    def do_evaluation(self):
        register_ids = np.unique(self.imm_classes) ## đếm xem có bao nhiêu identity trong dataset aka có bao nhiêu người có mặt trong dataset :D
        print(">>>> [base info] embs:", self.embs.shape, "imm_classes:", self.imm_classes.shape, "register_ids:", register_ids.shape)

        register_base_embs = np.array([]).reshape(0, self.embs.shape[-1]) # lưu vector đại diện của từng identity
        register_base_dists = []
        for register_id in tqdm(register_ids, "Evaluating"):
            # với từng identity: tìm các hình chứa gương mặt của người đó
            pos_pick_cond = self.imm_classes == register_id
            # lấy vector của các gương mặt đó
            pos_embs = self.embs[pos_pick_cond]
            # tạo ra vector đại diện cho identity đó : sum các vector gương mặt, sau đó normalize
            register_base_emb = normalize([np.sum(pos_embs, 0)])[0]
            # tính similarity của vector đại diện tới toàn bộ vector trong dataset
            register_base_dist = self.dist_func(self.embs, register_base_emb)
            register_base_dists.append(register_base_dist) # lưu kết quả vào 1 list
            register_base_embs = np.vstack([register_base_embs, register_base_emb])
        # save 1000 vector đại diện
        new_path = self.output_dir.replace(os.path.basename(self.output_dir),"processed_1000embedding.npz")
        print("saving vector đại diện tại: ",new_path)
        np.savez(new_path,embs =register_base_embs)
        register_base_dists = np.array(register_base_dists).T # similarity (cosine similarity) của toàn bộ identity tới toàn bộ vector trong dataset
        # cosine similarity from one image to each class
        print(register_base_dists.shape) # như vậy nó có shape 4720x1000

        # đồng thời theo chiều ngược lại : 1 ảnh (trong 4720 ảnh trong dataset), sẽ dc tính độ tương tự với 1000 vector đại diện
        ### bắt đầu quá trình tính toán accuracy

        # register_base_dists.argmax(1) => tìm identity tương tự nhất cho mỗi ảnh
        # accuracy = số lượng ảnh mà model detect identity đúng / số lượng ảnh (4720)
        accuracy = (register_base_dists.argmax(1) == self.imm_classes).sum() / register_base_dists.shape[0]
        print("register_ids shape: ",register_ids.shape)
        print("self.imm_classes shape: ",self.imm_classes.shape)

        # tạo 1 array có 4720 dòng x 1000 cột => mỗi dòng là 1 hình, hình dc predict có identity nào thì giá trị cột đó =1
        reg_pos_cond = np.equal(register_ids, np.expand_dims(self.imm_classes, 1))
        print(reg_pos_cond.shape) # array co 1 nghin cot, gia tri tai cot label =1

        # tính similarity của hình đó với vector identity gần nhất (positive prediction)
        reg_pos_dists = register_base_dists[reg_pos_cond].ravel()
        print(reg_pos_dists.shape) # 4720
        # similarity của các hình với các 999 vector identity xa hơn (999 negative prediction)
        reg_neg_dists = register_base_dists[np.logical_not(reg_pos_cond)].ravel()
        print(reg_neg_dists.shape) # 4720*999
        # turn it into a binary classification
        # label: tất cả prediction của model (positive hay negative) đều dc flatten
        # score: similarity tương ứng của model cho các quyết định đó
        label = np.concatenate([np.ones_like(reg_pos_dists), np.zeros_like(reg_neg_dists)])
        score = np.concatenate([reg_pos_dists, reg_neg_dists]) #distance tai cot co label va k co label
        return accuracy,score,label

def plot_tpr_far(score, label, new_figure=True, label_prefix=""):
    fpr, tpr, _ = roc_curve(label, score)
    roc_auc = auc(fpr, tpr)

    fpr_show = [10 ** (-ii) for ii in range(1, 7)[::-1]]
    fpr_reverse, tpr_reverse = fpr[::-1], tpr[::-1]
    tpr_show = [tpr_reverse[np.argmin(abs(fpr_reverse - ii))] for ii in fpr_show]
    print(pd.DataFrame({"FPR": fpr_show, "TPR": tpr_show}).set_index("FPR").T.to_markdown())

    try:
        import matplotlib.pyplot as plt

        fig = plt.figure() if new_figure else None
        label = "AUC = %0.4f%%" % (roc_auc * 100)
        if label_prefix and len(label_prefix) > 0:
            label = label_prefix + " " + label
        plt.plot(fpr, tpr, lw=1, label=label)
        plt.xlim([10 ** -6, 0.1])
        plt.xscale("log")
        plt.xticks(fpr_show)
        plt.xlabel("False Positive Rate")
        plt.ylim([0, 1.0])
        plt.yticks(np.linspace(0, 1.0, 8, endpoint=True))
        plt.ylabel("True Positive Rate")

        plt.grid(linestyle="--", linewidth=1)
        plt.title("ROC")
        plt.legend(loc="lower right")
        plt.tight_layout()
        plt.show()
    except:
        print("matplotlib plot failed")
        fig = None
    return fig

# %%
os.getcwd()
# Out:
# '/content'

# %%
demo_image = Eval_image("/content/drive/MyDrive/LDS8_new_content/b9_face_recognition_p2/data/GhostFaceNet_W1.3_S1_ArcFace.h5", "./train/train", output_dir="/content/drive/MyDrive/LDS8_new_content/b9_face_recognition_p2/data/root_embs/vn2db.npz",root_img_path="./train/train")
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# begin serving
# 100%|██████████| 4720/4720 [18:14<00:00,  4.31it/s]
# file chứa 4720 vector được save tại

# %%
demo_image = Eval_image("/content/drive/MyDrive/LDS8_new_content/b9_face_recognition_p2/data/GhostFaceNet_W1.3_S1_ArcFace.h5", "./train/train", output_dir="/content/drive/MyDrive/LDS8_new_content/b9_face_recognition_p2/data/root_embs/vn2db.npz",root_img_path="./train/train")
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# begin serving
# >>>> Reloading from backup: /content/drive/MyDrive/LDS8_new_content/b9_face_recognition_p2/data/root_embs/vn2db.npz

# %%
accuracy, score, label = demo_image.do_evaluation()
# Out:
# >>>> [base info] embs: (4720, 512) imm_classes: (4720,) register_ids: (1000,)
# Evaluating: 100%|██████████| 1000/1000 [00:05<00:00, 174.84it/s]
# saving vector đại diện tại:  /content/drive/MyDrive/LDS8_new_content/b9_face_recognition_p2/data/root_embs/processed_1000embedding.npz
# (4720, 1000)
# register_ids shape:  (1000,)
# self.imm_classes shape:  (4720,)
# (4720, 1000)
# (4720,)
# (4715280,)

# %% [markdown]
# # trong output của cell bên trên, vector đại diện dc save tại: /content/drive/MyDrive/LDS8_new_content/b9_face_recognition_p2/data/root_embs/processed_1000embedding.npz

# %%
accuracy
# Out:
# 0.9328389830508474

# %%
accuracy
# Out:
# 0.9328389830508474

# %%
plot_tpr_far(score, label, new_figure=True, label_prefix="")
# Out:
# |     |    1e-06 |    1e-05 |   0.0001 |    0.001 |    0.01 |      0.1 |
# |:----|---------:|---------:|---------:|---------:|--------:|---------:|
# | TPR | 0.501907 | 0.686864 | 0.841314 | 0.935593 | 0.98178 | 0.998517 |
