# %%
# !git clone https://github.com/eric-le-12/segmentbox.git
# Out:
# Cloning into 'segmentbox'...

# %%
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 58.8/58.8 KB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 85.0/85.0 KB 2.4 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      -------------------------------------- 106.7/106.7 KB 2.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 500.7/500.7 KB 3.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 38.1/38.1 MB 8.4 MB/s eta 0:00:00
# ...
#      -------------------------------------- 125.7/125.7 KB 7.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 78.3/78.3 KB ? eta 0:00:00
# ...
#      -------------------------------------- 105.9/105.9 KB 6.0 MB/s eta 0:00:00
# ...
