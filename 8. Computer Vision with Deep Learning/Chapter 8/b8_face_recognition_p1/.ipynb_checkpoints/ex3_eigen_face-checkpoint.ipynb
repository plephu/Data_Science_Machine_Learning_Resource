# %% [markdown]
# # Yêu cầu:
# 1. Đọc bộ dataset nằm trong folder data/eigenface_data
# 2. Sử dụng Eigenface xây dựng mô hình nhận diện gương mặt
# 3. Tính mean face, random face
# 4. Report độ chính xác và đánh giá

# %% [markdown]
# ## Exercise. How do we do Face Recognition In the Past??
# ## >> Using EigenFace

# %% [markdown]
# ### 1. Import data

# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Read face image from zip file on the fly
faces = {}
for folder in os.listdir("eigenface_data"):
    for img in os.listdir("eigenface_data/"+folder):
        img_path  = "eigenface_data/"+folder+"/"+img
        faces[img_path] = cv2.imread(img_path,cv2.IMREAD_GRAYSCALE)

# %%
# Show sample faces using matplotlib
fig, axes = plt.subplots(4,4,sharex=True,sharey=True,figsize=(8,10))
faceimages = list(faces.values())[-16:] # take last 16 images
for i in range(16):
    axes[i%4][i//4].imshow(faceimages[i], cmap="gray")
print("Showing sample faces")
plt.show()
# Out:
# Showing sample faces

# %%
# Print some details
faceshape = list(faces.values())[0].shape
print("Face image shape:", faceshape)

classes = set(filename.split("/")[1] for filename in faces.keys())
print("Number of classes:", len(classes))
print("Number of images:", len(faces))
# Out:
# Face image shape: (112, 92)
# Number of classes: 40
# Number of images: 400

# %% [markdown]
# ## 2. Train test split

# %%
classes = list(filename.split("/")[1] for filename in faces.keys())

# %%
import pandas as pd
data = pd.DataFrame({'image':list(faces.keys()),'label':classes})

# %% [markdown]
# #### Take 1 row of each group to become the test set

# %%
X_test = data.groupby('label').nth(0)

# %%
X_test
# Out:
#                         image label
# 0     eigenface_data/s1/1.pgm    s1
# 10   eigenface_data/s10/1.pgm   s10
# 20   eigenface_data/s11/1.pgm   s11
# 30   eigenface_data/s12/1.pgm   s12
# 40   eigenface_data/s13/1.pgm   s13
# 50   eigenface_data/s14/1.pgm   s14
# 60   eigenface_data/s15/1.pgm   s15
# 70   eigenface_data/s16/1.pgm   s16
# 80   eigenface_data/s17/1.pgm   s17
# 90   eigenface_data/s18/1.pgm   s18
# 100  eigenface_data/s19/1.pgm   s19
# 110   eigenface_data/s2/1.pgm    s2
# 120  eigenface_data/s20/1.pgm   s20
# 130  eigenface_data/s21/1.pgm   s21
# 140  eigenface_data/s22/1.pgm   s22
# 150  eigenface_data/s23/1.pgm   s23
# 160  eigenface_data/s24/1.pgm   s24
# 170  eigenface_data/s25/1.pgm   s25
# 180  eigenface_data/s26/1.pgm   s26
# 190  eigenface_data/s27/1.pgm   s27
# 200  eigenface_data/s28/1.pgm   s28
# 210  eigenface_data/s29/1.pgm   s29
# 220   eigenface_data/s3/1.pgm    s3
# 230  eigenface_data/s30/1.pgm   s30
# 240  eigenface_data/s31/1.pgm   s31
# 250  eigenface_data/s32/1.pgm   s32
# 260  eigenface_data/s33/1.pgm   s33
# 270  eigenface_data/s34/1.pgm   s34
# 280  eigenface_data/s35/1.pgm   s35
# 290  eigenface_data/s36/1.pgm   s36
# 300  eigenface_data/s37/1.pgm   s37
# 310  eigenface_data/s38/1.pgm   s38
# 320  eigenface_data/s39/1.pgm   s39
# 330   eigenface_data/s4/1.pgm    s4
# 340  eigenface_data/s40/1.pgm   s40
# 350   eigenface_data/s5/1.pgm    s5
# 360   eigenface_data/s6/1.pgm    s6
# 370   eigenface_data/s7/1.pgm    s7
# 380   eigenface_data/s8/1.pgm    s8
# 390   eigenface_data/s9/1.pgm    s9

# %%
X_test.label.unique()
# Out:
# array(['s1', 's10', 's11', 's12', 's13', 's14', 's15', 's16', 's17',
#        's18', 's19', 's2', 's20', 's21', 's22', 's23', 's24', 's25',
#        's26', 's27', 's28', 's29', 's3', 's30', 's31', 's32', 's33',
#        's34', 's35', 's36', 's37', 's38', 's39', 's4', 's40', 's5', 's6',
#        's7', 's8', 's9'], dtype=object)

# %%
len(X_test.label.unique())
# Out:
# 40

# %%
train_index = np.array(set(data.index)-set(X_test.index))
X_train = data.loc[train_index,:]

# %%
X_train
# Out:
#                         image label
# 1    eigenface_data/s1/10.pgm    s1
# 2     eigenface_data/s1/2.pgm    s1
# 3     eigenface_data/s1/3.pgm    s1
# 4     eigenface_data/s1/4.pgm    s1
# 5     eigenface_data/s1/5.pgm    s1
# ..                        ...   ...
# 395   eigenface_data/s9/5.pgm    s9
# 396   eigenface_data/s9/6.pgm    s9
# 397   eigenface_data/s9/7.pgm    s9
# 398   eigenface_data/s9/8.pgm    s9
# 399   eigenface_data/s9/9.pgm    s9
#
# [360 rows x 2 columns]

# %% [markdown]
# ## 3. Do the eigenFace

# %%
face_matrix = []
for img in X_train.image.to_list():
    face_matrix.append(faces[img].flatten())

# %%
face_matrix = np.array(face_matrix)

# %%
face_matrix.shape
# Out:
# (360, 10304)

# %%
# Apply PCA and take first K principal components as eigenfaces
from sklearn.decomposition import PCA

pca = PCA().fit(face_matrix)
n_components = 50
eigenfaces = pca.components_[:n_components]

# %%
# Show the first 16 eigenfaces
fig, axes = plt.subplots(4,4,sharex=True,sharey=True,figsize=(8,10))
for i in range(16):
    axes[i%4][i//4].imshow(eigenfaces[i].reshape(faceshape), cmap="gray")
print("Showing the eigenfaces")
plt.show()
# Out:
# Showing the eigenfaces

# %% [markdown]
# ## 4. Reconstruct Faces using PCA

# %%
weights = eigenfaces @ (face_matrix - pca.mean_).T
print("Shape of the weight matrix:", weights.shape)
# Out:
# Shape of the weight matrix: (50, 360)

# %% [markdown]
# ## 5. Perform Test

# %%
test_labels = X_test.label.to_list()
train_labels = X_train.label.to_list()
predictions = []
for img in X_test.image.to_list():
    query = faces[img].reshape(1,-1) #reshape and get the current query face
    query_weight = eigenfaces @ (query - pca.mean_).T
    euclidean_distance = np.linalg.norm(weights - query_weight, axis=0)
    best_match = np.argmin(euclidean_distance)
    predictions.append(train_labels[best_match])

# %%
fig, axes = plt.subplots(1,2,sharex=True,sharey=True,figsize=(8,6))
axes[0].imshow(query.reshape(faceshape), cmap="gray")
axes[0].set_title("Query")
axes[1].imshow(face_matrix[best_match].reshape(faceshape), cmap="gray")
axes[1].set_title("Best match")
plt.show()

# %%
print(rp(test_labels,predictions))
# Out:
#               precision    recall  f1-score   support
#
#           s1       1.00      1.00      1.00         1
#          s10       1.00      1.00      1.00         1
#          s11       1.00      1.00      1.00         1
#          s12       1.00      1.00      1.00         1
#          s13       1.00      1.00      1.00         1
#          s14       1.00      1.00      1.00         1
#          s15       1.00      1.00      1.00         1
#          s16       1.00      1.00      1.00         1
#          s17       1.00      1.00      1.00         1
#          s18       1.00      1.00      1.00         1
#          s19       1.00      1.00      1.00         1
#           s2       1.00      1.00      1.00         1
#          s20       1.00      1.00      1.00         1
#          s21       1.00      1.00      1.00         1
#          s22       1.00      1.00      1.00         1
#          s23       1.00      1.00      1.00         1
#          s24       1.00      1.00      1.00         1
#          s25       1.00      1.00      1.00         1
#          s26       1.00      1.00      1.00         1
#          s27       1.00      1.00      1.00         1
#          s28       1.00      1.00      1.00         1
#          s29       1.00      1.00      1.00         1
#           s3       1.00      1.00      1.00         1
#          s30       1.00      1.00      1.00         1
#          s31       1.00      1.00      1.00         1
#          s32       1.00      1.00      1.00         1
#          s33       1.00      1.00      1.00         1
#          s34       1.00      1.00      1.00         1
#          s35       0.00      0.00      0.00         1
#          s36       1.00      1.00      1.00         1
#          s37       1.00      1.00      1.00         1
#          s38       1.00      1.00      1.00         1
#          s39       1.00      1.00      1.00         1
#           s4       1.00      1.00      1.00         1
#          s40       0.50      1.00      0.67         1
#           s5       1.00      1.00      1.00         1
#           s6       1.00      1.00      1.00         1
#           s7       1.00      1.00      1.00         1
#           s8       1.00      1.00      1.00         1
#           s9       1.00      1.00      1.00         1
#
#     accuracy                           0.97        40
#    macro avg       0.96      0.97      0.97        40
# weighted avg       0.96      0.97      0.97        40
# C:\Users\DEMO_ACCOUNT\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DEMO_ACCOUNT\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DEMO_ACCOUNT\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
...
# Visualize the mean face and random face
fig, axes = plt.subplots(1,2,sharex=True,sharey=True,figsize=(8,6))
axes[0].imshow(pca.mean_.reshape(faceshape), cmap="gray")
axes[0].set_title("Mean face")
random_weights = np.random.randn(n_components) * weights.std()
newface = random_weights @ eigenfaces + pca.mean_
axes[1].imshow(newface.reshape(faceshape), cmap="gray")
axes[1].set_title("Random face")
plt.show()
